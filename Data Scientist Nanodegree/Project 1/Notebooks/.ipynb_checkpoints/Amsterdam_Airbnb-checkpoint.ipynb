# %% [markdown]
# # Analysis of Airbnb listings in Amsterdam

# %% [markdown]
# ## Introduction
#
# In this project we analyze the trends in the price, reviews and availability of Airbnb listings in Amsterdam using the CRISP-DM process.
#
# CRoss Industry Standard Process for Data Mining (CRISP-DM) is a open standard process model that is used for data mining, analytics and data science projects [1,2].
#
# CRISP-DM generally has the following sequential phases:
#
#     1) Business understanding – What does the business need?
#     2) Data understanding – What data do we have / need? Is it clean?
#     3) Data preparation – How do we organize the data for modeling?
#     4) Modeling – What modeling techniques should we apply?
#     5) Evaluation – Which model best meets the business objectives?
#     6) Deployment – How do stakeholders access the results?
#
# Here, we will go through each of these steps.
#
# References
#
# [1] https://www.datascience-pm.com/crisp-dm-2/
#
# [2] https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining
#
# [3] https://www.theguardian.com/cities/2016/oct/06/the-airbnb-effect-amsterdam-fairbnb-property-prices-communities
#
# [4] https://citymonitor.ai/economy/airbnb-getting-blamed-amsterdam-s-housing-crisis-so-city-council-going-war-against-airbnb
#
# [5] https://www.dutchnews.nl/news/2022/10/airbnb-style-rentals-harmful-to-amsterdam-says-tourism-chief/
#
# [6] https://www.lonelyplanet.com/news/amsterdam-bans-airbnb
#
# [7] https://www.reuters.com/article/us-netherlands-airbnb-amsterdam-idUSKBN2B81NS
#
# [8] https://www.amsterdam.nl/en/housing/holiday-rentals/applying-permit/
#
# [9] https://www.airbnb.co.in/help/article/860#:~:text=According%20to%20Dutch%20regulations%2C%20you,a%20short%20term%20stay%20license.
#
# ___

# %% [markdown]
# ## 1) Business Understanding
#
# Amsterdam is a popular tourist destination in the Netherlands. With its picturesque canals and bridges, historic homes and sights including the Anne Frank house and Van Gogh museum, Amsterdam attracts a lot of tourists through out the year. This makes holiday rental homes like Airbnbs a lucrative option for the locals to earn an additional income.
#
# However, there has been claims that the popularity of Airbnbs in Amsterdam has led to gentrification, thereby driving up real-estate prices and increasing the risk of a housing market bubble [3, 4]. This also has created a shortage in housing for locals, especially in popular tourist place like the Center of Amsterdam [5].
#
# To tackle these problems, the Municipality of Amstedam has taken some stringent measures including a permit system, that limits renting out homes to tourists for a maximum of 30 nights per year to a group of atmost 4 guests [6, 7]. Short-term rentals in Amsterdam must either be classified as a holiday rental or a bed & breakfast (B&Bs), with different regulations applying for each of these two categories. Non-compliance to the regulations stipulated by the Municipality can lead to fines upto the tune of 9000 euros [8].
#
# The regulations for holiday rentals include the following [8,9]:
#
#     1) The property must be the main residence of the host.
#     2) Only the main resident may rent their entire primary home to others, and cannot be present during the duration of the rental.
#     3) One can rent for a maximum of 30 nights per year.
#     4) One can only rent to a maximum of four people at once.
#
#
# The regulations for B&Bs include the following [8,9]:
#
#     1) A maximum of 40% of your residence may be rented out.
#     2) You may not rent an independent living space (for example with a private kitchen or separate entrance).
#     3) One can only rent to a maximum of four people at once.
#     4) Only the main resident can rent the space, and must be present during the rental.
#     5) There are no limit on the number of nights that a listing can be rented out and can be rented the entire year.
#
# Such regulations have made it difficult for new hosts to break into the short-rental business in Amsterdam. In this project, we will try to answer a few questions that will help new hosts in making informed decisions about renting their property in Amsterdam.
#
# We will try to answer the following questions:
#
#     1) Which neighbourhood is the most popular among tourists in Amsterdam? What are the average prices in the neighbourhoods? Is there a trend in the prices and reviews for the neighbourhoods?
#     2) What are the type of listings in Amsterdam and what is their average price? What are the most sought-after amenities provided by hosts in Amsterdam?
#     3) What time of the year is the demand high for listings in Amsterdam? How does the price of a listing change through the year?
#     4) What factors affect the price of a listing?
#     5) How effective are the regulations imposed by the municipality? Are there any listings that are breaking the rules?
#
# ____

# %% [markdown]
# ## 2) Data Understanding
#
# The Airbnb Amsterdam dataset used in the project can be found here: http://insideairbnb.com/get-the-data/
#
# The following files were downloaded and can be found in the folder ~/Project-1/Data/
#
#     - calendar.csv - Detailed calendar data inlcuding the price, availability etc
#     - listings.csv - Detailed description of the listings including price, review scores, location etc
#     - listings_summary.csv - Summary of all the listings in Amsterdam
#     - neighborhoods.csv - List of the neighborhoods in Amsterdam
#     - neighbourhoods.geojson - GeoJSON file of neighbourhoods of Amsterdam
#     - reviews.csv - Detailed reviews for the listings
#     - reviews_summary.csv - Details about listing and the date of review
#
# We will take a look at some of these files and see what data will be useful to us in answering the questions posed above and what data cleaning steps are necessary.

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno 
import datetime as dt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# render figures directly in the notebook:
# %matplotlib inline

# render higher resolution images:
# %config InlineBackend.figure_format = 'retina'

pd.set_option('display.max_rows', 500)

# %%
# Reading the datasets 

calendar = pd.read_csv('../Data/calendar.csv')
listings = pd.read_csv('../Data/listings.csv')
listings_summary = pd.read_csv ('../Data/listings_summary.csv')
neighbourhoods = pd.read_csv('../Data/neighbourhoods.csv')
reviews = pd.read_csv('../Data/reviews.csv')
reviews_summary = pd.read_csv('../Data/reviews_summary.csv')

# %%
# Displaying the datasets

calendar
# Out:
#          listing_id        date available    price adjusted_price  \
# 0              2818  2022-09-07         f   $49.00         $49.00
# 1              2818  2022-09-08         f   $49.00         $49.00
# 2              2818  2022-09-09         f   $49.00         $49.00
# 3              2818  2022-09-10         f   $49.00         $49.00
# 4              2818  2022-09-11         f   $49.00         $49.00
# ...             ...         ...       ...      ...            ...
# 2515206      515088  2023-09-02         t  $120.00        $120.00
# 2515207      515088  2023-09-03         t  $120.00        $120.00
# 2515208      515088  2023-09-04         t  $120.00        $120.00
# 2515209      515088  2023-09-05         t  $120.00        $120.00
# 2515210      515088  2023-09-06         t  $120.00        $120.00
#
#          minimum_nights  maximum_nights
# 0                   3.0          1125.0
# 1                   3.0          1125.0
# 2                   3.0          1125.0
# 3                   3.0          1125.0
# 4                   3.0          1125.0
# ...                 ...             ...
# 2515206             2.0            20.0
# 2515207             2.0            20.0
# 2515208             2.0            20.0
# 2515209             2.0            20.0
# 2515210             2.0            20.0
#
# [2515211 rows x 7 columns]

# %% [markdown]
# > __`calendar`__ dataframe has the listing IDs and the information whether a listing is available for a given day of the year and the corresponding price for that day.

# %%
listings
# Out:
#             id                            listing_url       scrape_id  \
# 0         2818      https://www.airbnb.com/rooms/2818  20220907151523
# 1        20168     https://www.airbnb.com/rooms/20168  20220907151523
# 2        27886     https://www.airbnb.com/rooms/27886  20220907151523
# 3        28871     https://www.airbnb.com/rooms/28871  20220907151523
# 4        29051     https://www.airbnb.com/rooms/29051  20220907151523
# ...        ...                                    ...             ...
# 6888  12690380  https://www.airbnb.com/rooms/12690380  20220907151523
# 6889  15005354  https://www.airbnb.com/rooms/15005354  20220907151523
# 6890  15171981  https://www.airbnb.com/rooms/15171981  20220907151523
# 6891  17567812  https://www.airbnb.com/rooms/17567812  20220907151523
# 6892  20084434  https://www.airbnb.com/rooms/20084434  20220907151523
#
#      last_scraped           source  \
# 0      2022-09-07      city scrape
# 1      2022-09-07  previous scrape
# 2      2022-09-07      city scrape
# 3      2022-09-07      city scrape
# 4      2022-09-07      city scrape
# ...           ...              ...
# 6888   2022-09-07  previous scrape
# 6889   2022-09-07  previous scrape
# 6890   2022-09-07  previous scrape
# 6891   2022-09-07  previous scrape
# 6892   2022-09-07  previous scrape
#
#                                                    name  \
# 0              Quiet Garden View Room & Super Fast WiFi
# 1          Studio with private bathroom in the centre 1
# 2     Romantic, stylish B&B houseboat in canal district
# 3                               Comfortable double room
# 4                               Comfortable single room
# ...                                                 ...
# 6888  Amsterdam, light big house 15 min from citycenter
# 6889                 Perfect family home near Amsterdam
# 6890  Child friendly house near Amsterdam - free par...
# 6891  Modern, spacious family home, 5 bedrooms-Amste...
# 6892  Single-family house (15m cycling center Amster...
#
#                                             description  \
# 0     Quiet Garden View Room & Super Fast WiFi<br />...
# 1     17th century Dutch townhouse in the heart of t...
# 2     Stylish and romantic houseboat on fantastic hi...
# 3     <b>The space</b><br />In a monumental house ri...
# 4     This room can also accomodate 2 people.  For a...
# ...                                                 ...
# 6888  We have a comfortable cosy house with a garden...
# 6889  Our house is situated in a quiet neighborhood ...
# 6890  Lovely family house with beautiful garden in a...
# 6891  Our house is located just 10 minutes away from...
# 6892  Careful! The house has one double bed, one sin...
#
#                                   neighborhood_overview  \
# 0     Indische Buurt ("Indies Neighborhood") is a ne...
# 1     Located just in between famous central canals....
# 2            Central, quiet, safe, clean and beautiful.
# 3          Flower market , Leidseplein , Rembrantsplein
# 4     the street is quite lively especially on weeke...
# ...                                                 ...
# 6888  Green and quiet lots of playgrounds for kids o...
# 6889  The house is situated in a beautiful neighbour...
# 6890  Located just outside of Amsterdam, in Duivendr...
# 6891  A very nice, quiet area, close to a park, fore...
# 6892  This is a little peace and quiet in the crazin...
#
#                                             picture_url   host_id  ...  \
# 0     https://a0.muscache.com/pictures/10272854/8dcc...      3159  ...
# 1     https://a0.muscache.com/pictures/69979628/fd6a...     59484  ...
# 2     https://a0.muscache.com/pictures/02c2da9d-660e...     97647  ...
# 3     https://a0.muscache.com/pictures/160889/362340...    124245  ...
# 4     https://a0.muscache.com/pictures/162009/bd6be2...    124245  ...
# ...                                                 ...       ...  ...
# 6888  https://a0.muscache.com/pictures/a100d408-769c...  15032494  ...
# 6889  https://a0.muscache.com/pictures/7a7d8058-c3f7...  46437958  ...
# 6890  https://a0.muscache.com/pictures/50ab12e8-c478...  96286859  ...
# 6891  https://a0.muscache.com/pictures/89bba873-f6c1...  55072916  ...
# 6892  https://a0.muscache.com/pictures/b68d763a-2c1f...  29435851  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.98                   4.69                4.82
# 1                           4.62                   4.87                4.49
# 2                           4.92                   4.89                4.79
# 3                           4.94                   4.96                4.83
# 4                           4.92                   4.87                4.77
# ...                          ...                    ...                 ...
# 6888                        4.68                   4.63                4.75
# 6889                        5.00                   4.89                4.83
# 6890                        4.71                   4.30                4.50
# 6891                        5.00                   4.75                4.88
# 6892                        4.86                   4.82                4.68
#
#                        license instant_bookable  \
# 0     0363 5F3A 5684 6750 D14D                t
# 1     0363 CBB3 2C10 0C2A 1E29                t
# 2     0363 974D 4986 7411 88D8                t
# 3     0363 607B EA74 0BD8 2F6F                f
# 4     0363 607B EA74 0BD8 2F6F                f
# ...                        ...              ...
# 6888                       NaN                f
# 6889                       NaN                f
# 6890                       NaN                f
# 6891                       NaN                f
# 6892                       NaN                f
#
#      calculated_host_listings_count  \
# 0                                 1
# 1                                 2
# 2                                 1
# 3                                 2
# 4                                 2
# ...                             ...
# 6888                              1
# 6889                              1
# 6890                              1
# 6891                              1
# 6892                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 6888                                           1
# 6889                                           1
# 6890                                           1
# 6891                                           1
# 6892                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               1
# 1                                               2
# 2                                               1
# 3                                               2
# 4                                               2
# ...                                           ...
# 6888                                            0
# 6889                                            0
# 6890                                            0
# 6891                                            0
# 6892                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              1.86
# 1                                              0              2.22
# 2                                              0              1.78
# 3                                              0              2.92
# 4                                              0              4.16
# ...                                          ...               ...
# 6888                                           0              0.36
# 6889                                           0              0.26
# 6890                                           0              0.29
# 6891                                           0              0.12
# 6892                                           0              0.37
#
# [6893 rows x 75 columns]

# %% [markdown]
# > __`listings`__ dataframe has the details about each listing available in Amsterdam. It has descriptors like location, review scores, property type, number of rooms etc.

# %%
listings_summary
# Out:
#             id                                               name   host_id  \
# 0         2818           Quiet Garden View Room & Super Fast WiFi      3159
# 1        20168       Studio with private bathroom in the centre 1     59484
# 2        27886  Romantic, stylish B&B houseboat in canal district     97647
# 3        28871                            Comfortable double room    124245
# 4        29051                            Comfortable single room    124245
# ...        ...                                                ...       ...
# 6888  12690380  Amsterdam, light big house 15 min from citycenter  15032494
# 6889  15005354                 Perfect family home near Amsterdam  46437958
# 6890  15171981  Child friendly house near Amsterdam - free par...  96286859
# 6891  17567812  Modern, spacious family home, 5 bedrooms-Amste...  55072916
# 6892  20084434  Single-family house (15m cycling center Amster...  29435851
#
#       host_name  neighbourhood_group                           neighbourhood  \
# 0        Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1     Alexander                  NaN                            Centrum-Oost
# 2          Flip                  NaN                            Centrum-West
# 3         Edwin                  NaN                            Centrum-West
# 4         Edwin                  NaN                            Centrum-Oost
# ...         ...                  ...                                     ...
# 6888    Lennard                  NaN                  Buitenveldert - Zuidas
# 6889        Gea                  NaN                  Buitenveldert - Zuidas
# 6890      Ischa                  NaN                         Watergraafsmeer
# 6891      Manon                  NaN                  Buitenveldert - Zuidas
# 6892  Stéphanie                  NaN                         Watergraafsmeer
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 0     52.36435    4.94358     Private room     49               3
# 1     52.36407    4.89393     Private room    106               1
# 2     52.38761    4.89188     Private room    136               2
# 3     52.36775    4.89092     Private room     75               2
# 4     52.36584    4.89111     Private room     55               2
# ...        ...        ...              ...    ...             ...
# 6888  52.31623    4.86718  Entire home/apt    300               3
# 6889  52.30863    4.86690  Entire home/apt    195               4
# 6890  52.33370    4.94073  Entire home/apt    449               1
# 6891  52.31309    4.84703  Entire home/apt    282               4
# 6892  52.33505    4.94517  Entire home/apt    200               3
#
#       number_of_reviews last_review  reviews_per_month  \
# 0                   305  2022-08-30               1.86
# 1                   339  2020-04-09               2.22
# 2                   231  2022-04-24               1.78
# 3                   428  2022-08-24               2.92
# 4                   582  2022-08-29               4.16
# ...                 ...         ...                ...
# 6888                 28  2022-08-20               0.36
# 6889                 18  2022-07-26               0.26
# 6890                 21  2022-08-07               0.29
# 6891                  8  2019-08-05               0.12
# 6892                 22  2022-08-21               0.37
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                                  1                14                     25
# 1                                  2                 0                      0
# 2                                  1               121                      8
# 3                                  2               117                     75
# 4                                  2               160                     86
# ...                              ...               ...                    ...
# 6888                               1                 0                      2
# 6889                               1                 0                      1
# 6890                               1                 0                      2
# 6891                               1                 0                      0
# 6892                               1                 0                     10
#
#                        license
# 0     0363 5F3A 5684 6750 D14D
# 1     0363 CBB3 2C10 0C2A 1E29
# 2     0363 974D 4986 7411 88D8
# 3     0363 607B EA74 0BD8 2F6F
# 4     0363 607B EA74 0BD8 2F6F
# ...                        ...
# 6888                       NaN
# 6889                       NaN
# 6890                       NaN
# 6891                       NaN
# 6892                       NaN
#
# [6893 rows x 18 columns]

# %% [markdown]
# > __`listings_summary`__ dataframe has the summary of each listing with the importan descriptors like id, name, location, price, number of reviews etc. This dataframe can be useful for visualizations.

# %%
neighbourhoods
# Out:
#     neighbourhood_group                           neighbourhood
# 0                   NaN                         Bijlmer-Centrum
# 1                   NaN                            Bijlmer-Oost
# 2                   NaN                           Bos en Lommer
# 3                   NaN                  Buitenveldert - Zuidas
# 4                   NaN                            Centrum-Oost
# 5                   NaN                            Centrum-West
# 6                   NaN                  De Aker - Nieuw Sloten
# 7                   NaN                  De Baarsjes - Oud-West
# 8                   NaN                 De Pijp - Rivierenbuurt
# 9                   NaN                   Gaasperdam - Driemond
# 10                  NaN                 Geuzenveld - Slotermeer
# 11                  NaN                IJburg - Zeeburgereiland
# 12                  NaN                              Noord-Oost
# 13                  NaN                              Noord-West
# 14                  NaN  Oostelijk Havengebied - Indische Buurt
# 15                  NaN                                  Osdorp
# 16                  NaN                               Oud-Noord
# 17                  NaN                                Oud-Oost
# 18                  NaN                             Slotervaart
# 19                  NaN                         Watergraafsmeer
# 20                  NaN                              Westerpark
# 21                  NaN                                    Zuid

# %% [markdown]
# > __`neighbourhood`__ dataframe has the list of 22 neighbourhoods in Amsterdam. This dataframe can be useful for visualization and for filtering/grouping.

# %%
reviews
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 0             2818                1191  2009-03-30        10952           Lam
# 1           515749             1671407  2012-07-09      2640670       Gregory
# 2           515749             1715674  2012-07-15      1032804       Michael
# 3             2818                1771  2009-04-24        12798         Alice
# 4           515749             1963378  2012-08-12       503786         Brian
# ...            ...                 ...         ...          ...           ...
# 342899    40606723  699774221938684093  2022-08-23    199478251          Hugo
# 342900    40606723  699844650325864717  2022-08-23    168768099         Cerys
# 342901    40606723  700487646276764037  2022-08-24    118306945         Anita
# 342902    40606723  700493829533962566  2022-08-24    403631092           Tos
# 342903    40606723  700503551410691003  2022-08-24    467451204         Laura
#
#                                                  comments
# 0       Daniel is really cool. The place was nice and ...
# 1       If you want the authentic Amsterdam houseboat ...
# 2       Unique and luxurious to be sure. I couldn't re...
# 3       Daniel is the most amazing host! His place is ...
# 4       My wife and I recently stopped in Amsterdam fo...
# ...                                                   ...
# 342899                                Excelente ubicación
# 342900  Would definitely recommend. Perfect location, ...
# 342901  Hôtel bien situé, personnel d’accueil chaleure...
# 342902  Sehr freundliche Personal. Vom Hotel aus kann ...
# 342903  L’Hotel2Stay si trova in una posizione molto c...
#
# [342904 rows x 6 columns]

# %% [markdown]
# > __`reviews`__ dataframe has the reviews for each listing on multiple dates by different reviewers.

# %%
reviews_summary
# Out:
#         listing_id        date
# 0           515749  2012-07-09
# 1             2818  2009-03-30
# 2           515749  2012-07-15
# 3           515749  2012-08-12
# 4           515749  2012-08-23
# ...            ...         ...
# 342899    40606723  2022-08-23
# 342900    40606723  2022-08-23
# 342901    40606723  2022-08-24
# 342902    40606723  2022-08-24
# 342903    40606723  2022-08-24
#
# [342904 rows x 2 columns]

# %% [markdown]
# > __`reviews_summary`__ has the reviews received by each listing and the corresponding date on which the review was posted.

# %%
# Checking the first 5 rows of a dataframe

calendar.head(5)
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        2818  2022-09-07         f  $49.00         $49.00             3.0
# 1        2818  2022-09-08         f  $49.00         $49.00             3.0
# 2        2818  2022-09-09         f  $49.00         $49.00             3.0
# 3        2818  2022-09-10         f  $49.00         $49.00             3.0
# 4        2818  2022-09-11         f  $49.00         $49.00             3.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
listings.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20220907151523   2022-09-07
# 1  20168  https://www.airbnb.com/rooms/20168  20220907151523   2022-09-07
# 2  27886  https://www.airbnb.com/rooms/27886  20220907151523   2022-09-07
# 3  28871  https://www.airbnb.com/rooms/28871  20220907151523   2022-09-07
# 4  29051  https://www.airbnb.com/rooms/29051  20220907151523   2022-09-07
#
#             source                                               name  \
# 0      city scrape           Quiet Garden View Room & Super Fast WiFi
# 1  previous scrape       Studio with private bathroom in the centre 1
# 2      city scrape  Romantic, stylish B&B houseboat in canal district
# 3      city scrape                            Comfortable double room
# 4      city scrape                            Comfortable single room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Stylish and romantic houseboat on fantastic hi...
# 3  <b>The space</b><br />In a monumental house ri...
# 4  This room can also accomodate 2 people.  For a...
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Located just in between famous central canals....
# 2         Central, quiet, safe, clean and beautiful.
# 3       Flower market , Leidseplein , Rembrantsplein
# 4  the street is quite lively especially on weeke...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/10272854/8dcc...     3159  ...
# 1  https://a0.muscache.com/pictures/69979628/fd6a...    59484  ...
# 2  https://a0.muscache.com/pictures/02c2da9d-660e...    97647  ...
# 3  https://a0.muscache.com/pictures/160889/362340...   124245  ...
# 4  https://a0.muscache.com/pictures/162009/bd6be2...   124245  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.98                   4.69                4.82
# 1                        4.62                   4.87                4.49
# 2                        4.92                   4.89                4.79
# 3                        4.94                   4.96                4.83
# 4                        4.92                   4.87                4.77
#
#                     license instant_bookable calculated_host_listings_count  \
# 0  0363 5F3A 5684 6750 D14D                t                              1
# 1  0363 CBB3 2C10 0C2A 1E29                t                              2
# 2  0363 974D 4986 7411 88D8                t                              1
# 3  0363 607B EA74 0BD8 2F6F                f                              2
# 4  0363 607B EA74 0BD8 2F6F                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            1
# 3                                            2
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.86
# 1                                           0              2.22
# 2                                           0              1.78
# 3                                           0              2.92
# 4                                           0              4.16
#
# [5 rows x 75 columns]

# %%
listings_summary.head(5)
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871                            Comfortable double room   124245
# 4  29051                            Comfortable single room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Flip                  NaN                            Centrum-West
# 3      Edwin                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-Oost
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  52.36435    4.94358  Private room     49               3
# 1  52.36407    4.89393  Private room    106               1
# 2  52.38761    4.89188  Private room    136               2
# 3  52.36775    4.89092  Private room     75               2
# 4  52.36584    4.89111  Private room     55               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                305  2022-08-30               1.86
# 1                339  2020-04-09               2.22
# 2                231  2022-04-24               1.78
# 3                428  2022-08-24               2.92
# 4                582  2022-08-29               4.16
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1                14                     25
# 1                               2                 0                      0
# 2                               1               121                      8
# 3                               2               117                     75
# 4                               2               160                     86
#
#                     license
# 0  0363 5F3A 5684 6750 D14D
# 1  0363 CBB3 2C10 0C2A 1E29
# 2  0363 974D 4986 7411 88D8
# 3  0363 607B EA74 0BD8 2F6F
# 4  0363 607B EA74 0BD8 2F6F

# %%
neighbourhoods.head(5)
# Out:
#    neighbourhood_group           neighbourhood
# 0                  NaN         Bijlmer-Centrum
# 1                  NaN            Bijlmer-Oost
# 2                  NaN           Bos en Lommer
# 3                  NaN  Buitenveldert - Zuidas
# 4                  NaN            Centrum-Oost

# %%
reviews.head(5)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0        2818     1191  2009-03-30        10952           Lam
# 1      515749  1671407  2012-07-09      2640670       Gregory
# 2      515749  1715674  2012-07-15      1032804       Michael
# 3        2818     1771  2009-04-24        12798         Alice
# 4      515749  1963378  2012-08-12       503786         Brian
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  If you want the authentic Amsterdam houseboat ...
# 2  Unique and luxurious to be sure. I couldn't re...
# 3  Daniel is the most amazing host! His place is ...
# 4  My wife and I recently stopped in Amsterdam fo...

# %%
reviews_summary.head(5)
# Out:
#    listing_id        date
# 0      515749  2012-07-09
# 1        2818  2009-03-30
# 2      515749  2012-07-15
# 3      515749  2012-08-12
# 4      515749  2012-08-23

# %% [markdown]
# > #### `Datatype mismatches`:
# > - The feature **`price`** is in dollars (probably of `object` type) and will have to converted to `float`.
# > - The are features in date format like **`date`**, **`last_review`** etc which can be converted to `datetime`
# > - We will check for other data mismatches in the following section
#
# > #### `Missing data & Duplicate data`:
# > - There are a few columns with missing data `(NaN)` values like **`neighbourhood_group`** and a few with duplicate values like **`last_scrape`**, **`scrape_id`** etc
# > - We will check for other such columns and handle them properly in the __`Data Preparation`__ section
#
# > #### `Unnecessary columns`:
# > - There are a lot of columns like **`listing_url`**, **`description`** etc which are not required to answer the questions that we have posed in the previous section
# > - These columns can be removed

# %%
# Checking the datatypes 

calendar.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price              object
# adjusted_price     object
# minimum_nights    float64
# maximum_nights    float64
# dtype: object

# %%
listings.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
# name                                             object
# description                                      object
# neighborhood_overview                            object
# picture_url                                      object
# host_id                                           int64
# host_url                                         object
# host_name                                        object
# host_since                                       object
# host_location                                    object
# host_about                                       object
# host_response_time                               object
# host_response_rate                               object
# host_acceptance_rate                             object
# host_is_superhost                                object
# host_thumbnail_url                               object
# host_picture_url                                 object
# host_neighbourhood                               object
# host_listings_count                               int64
# host_total_listings_count                         int64
# host_verifications                               object
# host_has_profile_pic                             object
# host_identity_verified                           object
# neighbourhood                                    object
# neighbourhood_cleansed                           object
# neighbourhood_group_cleansed                    float64
# latitude                                        float64
# longitude                                       float64
# property_type                                    object
# room_type                                        object
# accommodates                                      int64
# bathrooms                                       float64
# bathrooms_text                                   object
# bedrooms                                        float64
# beds                                            float64
# amenities                                        object
# price                                            object
# minimum_nights                                    int64
# maximum_nights                                    int64
# minimum_minimum_nights                          float64
# maximum_minimum_nights                          float64
# minimum_maximum_nights                          float64
# maximum_maximum_nights                          float64
# minimum_nights_avg_ntm                          float64
# maximum_nights_avg_ntm                          float64
# calendar_updated                                float64
# has_availability                                 object
# availability_30                                   int64
# availability_60                                   int64
# availability_90                                   int64
# availability_365                                  int64
# calendar_last_scraped                            object
# number_of_reviews                                 int64
# number_of_reviews_ltm                             int64
# number_of_reviews_l30d                            int64
# first_review                                     object
# last_review                                      object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# license                                          object
# instant_bookable                                 object
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# dtype: object

# %%
listings_summary.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
neighbourhoods.dtypes
# Out:
# neighbourhood_group    float64
# neighbourhood           object
# dtype: object

# %%
reviews.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
reviews_summary.dtypes
# Out:
# listing_id     int64
# date          object
# dtype: object

# %% [markdown]
# > - In all the dataframes, the datatypes are either `object`, `int64` or `float`
# > - There are no data of type of `bool` or `str` or `categorical` for instance
# > - We will further analyse the different columns of each datatype if there are any mismatches and if some of these columns can be deleted

# %%
def  func_return_list_dtypes(df):
    '''
    
    Function to return the list of columns with different dtypes in a dataframe
    
    Arguments:
    df - Dataframe with different columns 
    
    Returns:
    col_obj_type - List of columns of 'object' type
    col_num_type - List of columns of 'numeric' type
    
    '''
    
    col_obj_type = list(df.select_dtypes(include='object'))
    col_num_type = list(df.select_dtypes(include=['int64', 'float64']))
    
    return col_obj_type, col_num_type

# %%
# Checking the different 'Object' & 'Numeric' types 

calendar_obj, calendar_num = func_return_list_dtypes(calendar)

print('Object types: {}\n'.format(calendar_obj))
print('Numeric types: {}'.format(calendar_num))
# Out:
# Object types: ['date', 'available', 'price', 'adjusted_price']
#
# Numeric types: ['listing_id', 'minimum_nights', 'maximum_nights']

# %%
listings_obj, listings_num = func_return_list_dtypes(listings)

print('Object types: {}\n'.format(listings_obj))
print('Numeric types: {}'.format(listings_num))
# Out:
# Object types: ['listing_url', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type', 'bathrooms_text', 'amenities', 'price', 'has_availability', 'calendar_last_scraped', 'first_review', 'last_review', 'license', 'instant_bookable']
#
# Numeric types: ['id', 'scrape_id', 'host_id', 'host_listings_count', 'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
listings_summary_obj, listings_summary_num = func_return_list_dtypes(listings_summary)

print('Object types: {}\n'.format(listings_summary_obj))
print('Numeric types: {}'.format(listings_summary_num))
# Out:
# Object types: ['name', 'host_name', 'neighbourhood', 'room_type', 'last_review', 'license']
#
# Numeric types: ['id', 'host_id', 'neighbourhood_group', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm']

# %%
neighbourhoods_obj, neighbourhoods_num = func_return_list_dtypes(neighbourhoods)

print('Object types: {}\n'.format(neighbourhoods_obj))
print('Numeric types: {}'.format(neighbourhoods_num))
# Out:
# Object types: ['neighbourhood']
#
# Numeric types: ['neighbourhood_group']

# %%
reviews_obj, reviews_num = func_return_list_dtypes(reviews)

print('Object types: {}\n'.format(reviews_obj))
print('Numeric types: {}'.format(reviews_num))
# Out:
# Object types: ['date', 'reviewer_name', 'comments']
#
# Numeric types: ['listing_id', 'id', 'reviewer_id']

# %%
reviews_summary_obj, reviews_summary_num = func_return_list_dtypes(reviews_summary)

print('Object types: {}\n'.format(reviews_summary_obj))
print('Numeric types: {}'.format(reviews_summary_num))
# Out:
# Object types: ['date']
#
# Numeric types: ['listing_id']

# %% [markdown]
# > **`calendar`**:
#         > - **`date`**, **`available`** & **`price`** as type `object` and will have to be converted to `datetime`, `bool` and `float` respectively.
#         > - **`maximum_nights`** & **`adjusted_price`** column is not required and can be removed
#
# > **`listings`**:
#         > - This dataframe will be analysed in detail in the next section
#
# > **`listings_summary`**:
#         > - This dataframe seems to be a copy of the listings dataframe with all the important descriptors retained and all the right data type conversions.
#
# > **`neighbourhoods`**:
#         > - **`neighbourhood_group`** column is not required and can be removed
#
# > **`reviews`**:
#         > - **`date`** will have to be converted to `datetime`
#         > - **`reviewer_name`**, **`reviewer_id`** and **`id`** can be removed
#
# > **`reviews_summary`**:
#         > - This dataframe seems to be contain the same data in **`reviews`** and will not be used for further analysis

# %%
# List of columns to remove 

remove_from_calendar = ['maximum_nights', 'adjusted_price']
remove_from_neighbourhood = ['neighbourhood_group']
remove_from_review = ['reviewer_name', 'reviewer_id', 'id']

# %% [markdown]
# > Let's take a look at the **`listings`** dataframe and see which features are important to us and which can be removed. We will start with the `object` datatypes.

# %%
print('Object types: {}\n'.format(listings_obj))
# Out:
# Object types: ['listing_url', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type', 'bathrooms_text', 'amenities', 'price', 'has_availability', 'calendar_last_scraped', 'first_review', 'last_review', 'license', 'instant_bookable']

# %%
# We will remove all columns with 'url' in it as it is not useful to us

col_url = [col for col in listings_obj if 'url' in col]
col_url
# Out:
# ['listing_url',
#  'picture_url',
#  'host_url',
#  'host_thumbnail_url',
#  'host_picture_url']

# %%
# We will remove all columns with information about data scraping

col_scrap = [col for col in listings_obj if 'scrap' in col]
col_scrap
# Out:
# ['last_scraped', 'calendar_last_scraped']

# %%
# There are a lot of columns about the host of a listing. Lets take a look at them 

col_host = [col for col in listings_obj if 'host' in col]
col_host
# Out:
# ['host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified']

# %%
listings[col_host].head(5)
# Out:
#                                    host_url  host_name  host_since  \
# 0    https://www.airbnb.com/users/show/3159     Daniel  2008-09-24
# 1   https://www.airbnb.com/users/show/59484  Alexander  2009-12-02
# 2   https://www.airbnb.com/users/show/97647       Flip  2010-03-23
# 3  https://www.airbnb.com/users/show/124245      Edwin  2010-05-13
# 4  https://www.airbnb.com/users/show/124245      Edwin  2010-05-13
#
#             host_location                                         host_about  \
# 0  Amsterdam, Netherlands  Upon arriving in Amsterdam, one can imagine as...
# 1  Amsterdam, Netherlands                  + (Phone number hidden by Airbnb)
# 2  Amsterdam, Netherlands  Marjan works in "eye" the dutch filmmuseum, an...
# 3  Amsterdam, Netherlands                                                 Hi
# 4  Amsterdam, Netherlands                                                 Hi
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour               100%                 100%
# 1     within an hour               100%                  98%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                 100%
# 4     within an hour               100%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 t  https://a0.muscache.com/im/users/3159/profile_...
# 1                 f  https://a0.muscache.com/im/pictures/user/65092...
# 2                 f  https://a0.muscache.com/im/users/97647/profile...
# 3                 t  https://a0.muscache.com/im/pictures/user/9986b...
# 4                 t  https://a0.muscache.com/im/pictures/user/9986b...
#
#                                     host_picture_url   host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/3159/profile_...       Indische Buurt
# 1  https://a0.muscache.com/im/pictures/user/65092...       Grachtengordel
# 2  https://a0.muscache.com/im/users/97647/profile...  Westelijke Eilanden
# 3  https://a0.muscache.com/im/pictures/user/9986b...    Amsterdam Centrum
# 4  https://a0.muscache.com/im/pictures/user/9986b...    Amsterdam Centrum
#
#    host_verifications host_has_profile_pic host_identity_verified
# 0  ['email', 'phone']                    t                      t
# 1  ['email', 'phone']                    t                      t
# 2  ['email', 'phone']                    t                      t
# 3  ['email', 'phone']                    t                      t
# 4  ['email', 'phone']                    t                      t

# %% [markdown]
# > From the above data, we will keep **`host_name, 'host_since', 'host_response_time', 'host_response_rate', 'host_acceptance_rate','host_is_superhost','host_has_profile_pic', and  'host_identity_verified`**

# %%
# We will make a new list with the columns in 'listings' to keep and remove the rest of the columns with host information
# Let's write a function to do this 
def func_remove_from_list(col_list, keep_list):
    for i in keep_list:
        try:
            col_list.remove(i)
        except ValueError:
            pass
    return col_list

# %%
# Let's check the list again

keep_list = ['host_name', 'host_since', 'host_response_time', 'host_response_rate', 'host_acceptance_rate','host_is_superhost','host_has_profile_pic', 'host_identity_verified']
col_host = func_remove_from_list(col_host, keep_list)
col_host
# Out:
# ['host_url',
#  'host_location',
#  'host_about',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_verifications']

# %%
# There are a few columns about the neighbourhood of a listing. Lets take a look at them 

col_neigh = [col for col in listings_obj if 'neigh' in col]
col_neigh
# Out:
# ['neighborhood_overview',
#  'host_neighbourhood',
#  'neighbourhood',
#  'neighbourhood_cleansed']

# %%
listings[col_neigh].head(5)
# Out:
#                                neighborhood_overview   host_neighbourhood  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...       Indische Buurt
# 1  Located just in between famous central canals....       Grachtengordel
# 2         Central, quiet, safe, clean and beautiful.  Westelijke Eilanden
# 3       Flower market , Leidseplein , Rembrantsplein    Amsterdam Centrum
# 4  the street is quite lively especially on weeke...    Amsterdam Centrum
#
#                            neighbourhood  \
# 0  Amsterdam, North Holland, Netherlands
# 1  Amsterdam, North Holland, Netherlands
# 2  Amsterdam, North Holland, Netherlands
# 3  Amsterdam, North Holland, Netherlands
# 4  Amsterdam, North Holland, Netherlands
#
#                    neighbourhood_cleansed
# 0  Oostelijk Havengebied - Indische Buurt
# 1                            Centrum-Oost
# 2                            Centrum-West
# 3                            Centrum-West
# 4                            Centrum-Oost

# %% [markdown]
# > Here, we can remove **`neighborhood_overview`**. **`host_neighborhood`** will be removed along with the other 'host' columns. Let's check which of them have 22 unique values.

# %%
len(listings['neighbourhood'].unique()), len(listings['neighbourhood_cleansed'].unique())
# Out:
# (89, 22)

# %%
# Seems like 'neighbourhood_cleansed' is the only column we need to get the information about the neighbourhood of a listing and we will remove the rest

keep_list = ['neighbourhood_cleansed']
col_neigh = func_remove_from_list(col_neigh, keep_list)
col_neigh
# Out:
# ['neighborhood_overview', 'host_neighbourhood', 'neighbourhood']

# %%
# Let's check for other 'text' columns

col_text = []
for col in listings_obj:
    if(listings[col].astype('str').str.len() > 10).any():
        col_text.append(col)
    else:
        continue
col_text
# Out:
# ['listing_url',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_url',
#  'host_name',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_verifications',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'property_type',
#  'room_type',
#  'bathrooms_text',
#  'amenities',
#  'license']

# %%
# Fromt the above list, we will remove some of the columns that have not been listed yet

col_text = ['source', 'description', 'license']

# %%
# We will remove all columns with the same values

col_duplicate = []
for col in listings_obj:
    if(listings[col] == listings[col][0]).all():
        col_duplicate.append(col)
    else:
        continue
col_duplicate
# Out:
# []

# %%
remove_from_listings_obj = col_duplicate + col_host + col_neigh + col_scrap + col_text + col_url
remove_from_listings_obj
# Out:
# ['host_url',
#  'host_location',
#  'host_about',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_verifications',
#  'neighborhood_overview',
#  'host_neighbourhood',
#  'neighbourhood',
#  'last_scraped',
#  'calendar_last_scraped',
#  'source',
#  'description',
#  'license',
#  'listing_url',
#  'picture_url',
#  'host_url',
#  'host_thumbnail_url',
#  'host_picture_url']

# %%
len(listings_obj) - len(remove_from_listings_obj)
# Out:
# 15

# %% [markdown]
# > So we will be keeping only 9 columns of `objective` type. Let's take a look at columns of type `numeric` type. We will repeat the same steps that we did previously.

# %%
listings_num
# Out:
# ['id',
#  'scrape_id',
#  'host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
# We will remove all columns with the same values

col_duplicate = []
for col in listings_num:
    if(listings[col] == listings[col][0]).all():
        col_duplicate.append(col)
    else:
        continue
col_duplicate
# Out:
# ['scrape_id']

# %%
col_host = [col for col in listings_num if 'host' in col]
col_host
# Out:
# ['host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms']

# %%
listings[col_host].head(5)
# Out:
#    host_id  host_listings_count  host_total_listings_count  \
# 0     3159                    1                          1
# 1    59484                    5                          5
# 2    97647                    1                          1
# 3   124245                    2                          2
# 4   124245                    2                          2
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               1
# 3                               2
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             1
# 3                                             2
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0

# %%
# We will just keep 'calculated_host_listings_count' that gives the number of listings that a particular host have. We will remove the rest

keep_list = ['calculated_host_listings_count']
col_host = func_remove_from_list(col_host, keep_list)
col_host
# Out:
# ['host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms']

# %%
#  Let's look at the columns with the information about the nights for which a given listing can be booked
col_night = [col for col in listings_num if 'night' in col]
col_night
# Out:
# ['minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm']

# %%
listings[col_night].head(5)
# Out:
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3              28                     3.0
# 1               1             365                     1.0
# 2               2             356                     2.0
# 3               2            1825                     2.0
# 4               2             730                     2.0
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                     3.0                  1125.0                  1125.0
# 1                     1.0                  1125.0                  1125.0
# 2                     2.0                  1125.0                  1125.0
# 3                     2.0                  1825.0                  1825.0
# 4                     2.0                   730.0                   730.0
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm
# 0                     3.0                  1125.0
# 1                     1.0                  1125.0
# 2                     2.0                  1125.0
# 3                     2.0                  1825.0
# 4                     2.0                   730.0

# %%
# Looks like we have a lot of duplicate columns here. We will just keep the 'minimum_nights' & 'maximum_nights' columns. 

keep_list = ['minimum_nights', 'maximum_nights']
col_night = func_remove_from_list(col_night, keep_list)
col_night
# Out:
# ['minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm']

# %%
#  Let's look at the columns with the information about the reviews received by each listing
col_review = [col for col in listings_num if 'review' in col]
col_review
# Out:
# ['number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'reviews_per_month']

# %%
listings[col_review].head(5)
# Out:
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                305                     25                       1
# 1                339                      0                       0
# 2                231                      8                       0
# 3                428                     75                       5
# 4                582                     86                       7
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.89                    4.94                       5.00
# 1                  4.44                    4.69                       4.79
# 2                  4.94                    4.92                       4.95
# 3                  4.88                    4.94                       4.89
# 4                  4.79                    4.88                       4.84
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.97                         4.98                    4.69
# 1                   4.63                         4.62                    4.87
# 2                   4.95                         4.92                    4.89
# 3                   4.96                         4.94                    4.96
# 4                   4.92                         4.92                    4.87
#
#    review_scores_value  reviews_per_month
# 0                 4.82               1.86
# 1                 4.49               2.22
# 2                 4.79               1.78
# 3                 4.83               2.92
# 4                 4.77               4.16

# %% [markdown]
# > We will keep the 'number_of_reviews', 'number_of_review_l30d', 'review_scores_rating', 'review_scores_location', and 'reviews_per_month'

# %%
keep_list = ['number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_location', 'reviews_per_month']
col_review = func_remove_from_list(col_review, keep_list)
col_review
# Out:
# ['number_of_reviews_ltm',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_value']

# %%
#  Let's look at the columns with the information about the availability of each listing

col_avail = [col for col in listings_num if 'avail' in col]
col_avail
# Out:
# ['availability_30', 'availability_60', 'availability_90', 'availability_365']

# %%
listings[col_avail].head(5)
# Out:
#    availability_30  availability_60  availability_90  availability_365
# 0                1                9               14                14
# 1                0                0                0                 0
# 2                0                0               14               121
# 3                4                6                8               117
# 4                0                4                5               160

# %% [markdown]
# > These columns looks like they can have an affect on the price of a listing and hence, we will retain them.

# %%
remove_from_listings_num = col_duplicate + col_host + col_night + col_review
remove_from_listings_num
# Out:
# ['scrape_id',
#  'host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'number_of_reviews_ltm',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_value']

# %%
# Now we have all the columns to be removed from listings dataframe

remove_from_listings = remove_from_listings_num + remove_from_listings_obj

# %%
# Let's check the info about all the dataframes

calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515211 entries, 0 to 2515210
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 134.3+ MB

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6893 non-null   int64
#  1   listing_url                                   6893 non-null   object
#  2   scrape_id                                     6893 non-null   int64
#  3   last_scraped                                  6893 non-null   object
#  4   source                                        6893 non-null   object
#  5   name                                          6893 non-null   object
#  6   description                                   6877 non-null   object
#  7   neighborhood_overview                         4628 non-null   object
#  8   picture_url                                   6893 non-null   object
#  9   host_id                                       6893 non-null   int64
#  10  host_url                                      6893 non-null   object
#  11  host_name                                     6893 non-null   object
#  12  host_since                                    6893 non-null   object
#  13  host_location                                 6122 non-null   object
#  14  host_about                                    4132 non-null   object
#  15  host_response_time                            5236 non-null   object
#  16  host_response_rate                            5236 non-null   object
#  17  host_acceptance_rate                          6031 non-null   object
#  18  host_is_superhost                             6885 non-null   object
#  19  host_thumbnail_url                            6893 non-null   object
#  20  host_picture_url                              6893 non-null   object
#  21  host_neighbourhood                            3096 non-null   object
#  22  host_listings_count                           6893 non-null   int64
#  23  host_total_listings_count                     6893 non-null   int64
#  24  host_verifications                            6893 non-null   object
#  25  host_has_profile_pic                          6893 non-null   object
#  26  host_identity_verified                        6893 non-null   object
#  27  neighbourhood                                 4628 non-null   object
#  28  neighbourhood_cleansed                        6893 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      6893 non-null   float64
#  31  longitude                                     6893 non-null   float64
#  32  property_type                                 6893 non-null   object
#  33  room_type                                     6893 non-null   object
#  34  accommodates                                  6893 non-null   int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                6878 non-null   object
#  37  bedrooms                                      6578 non-null   float64
#  38  beds                                          6792 non-null   float64
#  39  amenities                                     6893 non-null   object
#  40  price                                         6893 non-null   object
#  41  minimum_nights                                6893 non-null   int64
#  42  maximum_nights                                6893 non-null   int64
#  43  minimum_minimum_nights                        6891 non-null   float64
#  44  maximum_minimum_nights                        6891 non-null   float64
#  45  minimum_maximum_nights                        6891 non-null   float64
#  46  maximum_maximum_nights                        6891 non-null   float64
#  47  minimum_nights_avg_ntm                        6891 non-null   float64
#  48  maximum_nights_avg_ntm                        6891 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              6893 non-null   object
#  51  availability_30                               6893 non-null   int64
#  52  availability_60                               6893 non-null   int64
#  53  availability_90                               6893 non-null   int64
#  54  availability_365                              6893 non-null   int64
#  55  calendar_last_scraped                         6893 non-null   object
#  56  number_of_reviews                             6893 non-null   int64
#  57  number_of_reviews_ltm                         6893 non-null   int64
#  58  number_of_reviews_l30d                        6893 non-null   int64
#  59  first_review                                  6247 non-null   object
#  60  last_review                                   6247 non-null   object
#  61  review_scores_rating                          6247 non-null   float64
#  62  review_scores_accuracy                        6242 non-null   float64
#  63  review_scores_cleanliness                     6242 non-null   float64
#  64  review_scores_checkin                         6242 non-null   float64
#  65  review_scores_communication                   6242 non-null   float64
#  66  review_scores_location                        6242 non-null   float64
#  67  review_scores_value                           6242 non-null   float64
#  68  license                                       6449 non-null   object
#  69  instant_bookable                              6893 non-null   object
#  70  calculated_host_listings_count                6893 non-null   int64
#  71  calculated_host_listings_count_entire_homes   6893 non-null   int64
#  72  calculated_host_listings_count_private_rooms  6893 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   6893 non-null   int64
#  74  reviews_per_month                             6247 non-null   float64
# dtypes: float64(21), int64(19), object(35)
# memory usage: 3.9+ MB

# %%
listings_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6893 non-null   int64
#  1   name                            6893 non-null   object
#  2   host_id                         6893 non-null   int64
#  3   host_name                       6893 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   6893 non-null   object
#  6   latitude                        6893 non-null   float64
#  7   longitude                       6893 non-null   float64
#  8   room_type                       6893 non-null   object
#  9   price                           6893 non-null   int64
#  10  minimum_nights                  6893 non-null   int64
#  11  number_of_reviews               6893 non-null   int64
#  12  last_review                     6247 non-null   object
#  13  reviews_per_month               6247 non-null   float64
#  14  calculated_host_listings_count  6893 non-null   int64
#  15  availability_365                6893 non-null   int64
#  16  number_of_reviews_ltm           6893 non-null   int64
#  17  license                         6449 non-null   object
# dtypes: float64(4), int64(8), object(6)
# memory usage: 969.5+ KB

# %%
neighbourhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        22 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 480.0+ bytes

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342904 entries, 0 to 342903
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     342904 non-null  int64
#  1   id             342904 non-null  int64
#  2   date           342904 non-null  object
#  3   reviewer_id    342904 non-null  int64
#  4   reviewer_name  342904 non-null  object
#  5   comments       342890 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# > - There are some missing values in all the dataframes.
# > - We can either drop the data (if it doesnt impact our analysis) or perform imputation using some statistical measure (mean, mode etc) or some assumptions about our data.
# > - We will do this in the next section.
#
# ___________

# %% [markdown]
# ## 3) Data Preparation:
#
# In this section we will organize the data that we need for the next modeling phase. The following data preparation steps will be done:
#
#     1) Removing columns that are not required
#     2) Handling/removing missing data
#     3) Handling datatype mismatch
#     4) Sanity checks on the data
#
# We will start by dropping all the columns that we do not need.

# %%
df_calendar = calendar.drop(remove_from_calendar, axis=1)
df_listings = listings.drop(remove_from_listings, axis=1)
df_neighbourhood = neighbourhoods.drop(remove_from_neighbourhood, axis=1)
df_reviews  = reviews.drop(remove_from_review, axis=1)

# %% [markdown]
# #### Handling missing data

# %%
# Let's check the remaining columns for missing data. We will use a function for this. 

def find_missing_cols_perc(df, perc):
    '''
    Function to print a list a columns in a dataframe with missing values
    
    Input:
    df - dataframe
    perc - percentage of missing values
    
    Output:
    List of columns with percentage of missing data greater than 'perc'
    
    '''
    print(df.columns[df.isnull().mean() > perc])

# %%
# Let's check for columns with any missing data (perc=0) and more than 50% missing data

find_missing_cols_perc(df_calendar, 0), find_missing_cols_perc(df_calendar, 0.5)
# Out:
# Index(['price', 'minimum_nights'], dtype='object')
# Index([], dtype='object')
# (None, None)

# %%
find_missing_cols_perc(df_listings, 0), find_missing_cols_perc(df_listings, 0.5)
# Out:
# Index(['host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'neighbourhood_group_cleansed', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'calendar_updated',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_location', 'reviews_per_month'],
#       dtype='object')
# Index(['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated'], dtype='object')
# (None, None)

# %%
find_missing_cols_perc(df_neighbourhood, 0), find_missing_cols_perc(df_neighbourhood, 0.5)
# Out:
# Index([], dtype='object')
# Index([], dtype='object')
# (None, None)

# %%
find_missing_cols_perc(df_reviews, 0), find_missing_cols_perc(df_reviews, 0.5)
# Out:
# Index(['comments'], dtype='object')
# Index([], dtype='object')
# (None, None)

# %% [markdown]
# Columns with missing value > 50%
#
# > The dataframes __`df_calendar`__, __`df_neighbourhood`__ and __`df_reviews`__ have no columns with missing values greater than 50%.
#
# > In __`df_listings`__, there are 3 columns - `'neighbourhood_group_cleansed'`, `'bathrooms'`, `'calendar_updated'` with more than 50% values missing. Let's take a look at eacth of them.

# %%
df_listings['neighbourhood_group_cleansed'].isnull().mean()
# Out:
# 1.0

# %%
df_listings['bathrooms'].isnull().mean()
# Out:
# 1.0

# %%
df_listings['calendar_updated'].isnull().mean()
# Out:
# 1.0

# %% [markdown]
# > It seems like these three columns are empty. We can remove them. We already have a descriptor for neighboorhood.
# > We will check later if there are other columns that gives us the same information which is missing i.e. number of bathroom.

# %%
df_listings.drop(['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated'], axis=1, inplace=True)

# %% [markdown]
# > Columns with any missing values
# > - __`df_calendar`__ has 2 columns with missing values - `'price'`, `'minimum_nights'`

# %%
df_calendar['price'].isnull().sum()
# Out:
# 4

# %%
df_calendar[df_calendar['price'].isnull()]
# Out:
#          listing_id        date available price  minimum_nights
# 1442107    52623412  2023-09-03         f   NaN             3.0
# 1442108    52623412  2023-09-04         f   NaN             3.0
# 1442109    52623412  2023-09-05         f   NaN             3.0
# 1442110    52623412  2023-09-06         f   NaN             3.0

# %% [markdown]
# > There are only 4 rows with missing price information. We can check if the same information is available in __`df_listings`__

# %%
df_listings[df_listings['id']==52623412]['price']
# Out:
# 5116    $145.00
# Name: price, dtype: object

# %%
# The price of the listing with id '52623412' is 145 dollars. We will use the same value 

df_calendar.loc[(df_calendar['price'].isna()) & (df_calendar['listing_id'] == 52623412), 'price'] = '$145.00'

# %%
# Checking whether the imputation worked

df_calendar['price'].isnull().sum()
# Out:
# 0

# %%
df_calendar['minimum_nights'].isnull().sum()
# Out:
# 354

# %% [markdown]
# > There are 354 missing values of `'minimum_nights'` in __`df_calendar`__. We will impute it with median value.

# %%
df_calendar['minimum_nights'].median()
# Out:
# 3.0

# %%
df_calendar.loc[(df_calendar['minimum_nights'].isna()), 'minimum_nights'] = 3.0

# %%
# Checking whether the imputation worked

df_calendar['minimum_nights'].isnull().sum()
# Out:
# 0

# %%
# Let's check for columns with any number of missing values in df_listings

find_missing_cols_perc(df_listings, 0)
# Out:
# Index(['host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'bathrooms_text', 'bedrooms', 'beds',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_location', 'reviews_per_month'],
#       dtype='object')

# %%
# Checking the amount of missing values in df_listings

df_listings[['host_response_time', 'host_response_rate', 'host_acceptance_rate','host_is_superhost', 'bathrooms_text', 'bedrooms', 'beds',
       'first_review', 'last_review', 'review_scores_rating', 'reviews_per_month']].isnull().mean()
# Out:
# host_response_time      0.240389
# host_response_rate      0.240389
# host_acceptance_rate    0.125054
# host_is_superhost       0.001161
# bathrooms_text          0.002176
# bedrooms                0.045699
# beds                    0.014653
# first_review            0.093718
# last_review             0.093718
# review_scores_rating    0.093718
# reviews_per_month       0.093718
# dtype: float64

# %% [markdown]
# > Three descriptors - `host_response_time`, `host_response_rate` and `host_acceptance_rate` have the most missing values.

# %%
df_listings[df_listings['host_response_rate'].isnull()]
# Out:
#                       id                                            name  \
# 8                  55709                 Bright Loft in Centre Amsterdam
# 11                 80635              TOP LOCATED Canalhouse B&B Jordaan
# 15                 97476      Spacious, bright apartment near Vondelpark
# 19                168769  SUPERLOCATED Room in  CANALHOUSE, Private bath
# 21                171054               Spacious apartment next to center
# ...                  ...                                             ...
# 6866            47775661         Aparthotel Adagio I 2 Bedroom Apartment
# 6867            48005583                      Aparthotel Adagio I Studio
# 6873            53639028             Aparthotel Adagio I Superior Studio
# 6881  615765212982184707             zonnige loft, vrij P, snel in  stad
# 6885             8573930               Spacious home near all facilities
#
#                              host_name  host_since host_response_time  \
# 8                           Jan-Willem  2010-10-16                NaN
# 11                                Riks  2011-03-11                NaN
# 15                              Rachel  2011-04-05                NaN
# 19                                Riks  2011-03-11                NaN
# 21                              Kamiel  2011-07-13                NaN
# ...                                ...         ...                ...
# 6866  Aparthotel Adagio Amsterdam City  2021-01-12                NaN
# 6867  Aparthotel Adagio Amsterdam City  2021-01-12                NaN
# 6873  Aparthotel Adagio Amsterdam City  2021-01-12                NaN
# 6881                             Karin  2014-02-08                NaN
# 6885                             Ulric  2013-04-26                NaN
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 8                   NaN                  50%                 f
# 11                  NaN                 100%                 t
# 15                  NaN                 100%                 f
# 19                  NaN                 100%                 t
# 21                  NaN                  NaN                 f
# ...                 ...                  ...               ...
# 6866                NaN                 100%                 f
# 6867                NaN                 100%                 f
# 6873                NaN                 100%                 f
# 6881                NaN                  25%                 f
# 6885                NaN                 100%                 t
#
#      host_has_profile_pic host_identity_verified  ... availability_365  \
# 8                       t                      t  ...                0
# 11                      t                      t  ...                0
# 15                      t                      f  ...                0
# 19                      t                      t  ...                0
# 21                      t                      f  ...                0
# ...                   ...                    ...  ...              ...
# 6866                    t                      t  ...                0
# 6867                    t                      t  ...                0
# 6873                    t                      t  ...                0
# 6881                    t                      t  ...                0
# 6885                    t                      t  ...                0
#
#       number_of_reviews  number_of_reviews_l30d first_review last_review  \
# 8                    63                       0   2010-12-06  2022-04-13
# 11                  228                       0   2011-03-23  2021-11-01
# 15                   55                       0   2011-06-06  2022-03-27
# 19                  268                       0   2011-09-28  2021-10-18
# 21                  103                       0   2011-07-18  2018-11-28
# ...                 ...                     ...          ...         ...
# 6866                  0                       0          NaN         NaN
# 6867                  2                       0   2022-03-20  2022-03-27
# 6873                  0                       0          NaN         NaN
# 6881                  1                       0   2022-05-24  2022-05-24
# 6885                 43                       3   2016-04-26  2022-08-15
#
#       review_scores_rating review_scores_location  instant_bookable  \
# 8                     4.95                   4.92                 f
# 11                    4.77                   4.95                 t
# 15                    4.89                   4.85                 f
# 19                    4.58                   4.96                 t
# 21                    4.75                   4.73                 f
# ...                    ...                    ...               ...
# 6866                   NaN                    NaN                 t
# 6867                  4.50                   4.50                 t
# 6873                   NaN                    NaN                 t
# 6881                  5.00                   5.00                 f
# 6885                  4.91                   4.57                 f
#
#       calculated_host_listings_count reviews_per_month
# 8                                  1              0.44
# 11                                 4              1.63
# 15                                 1              0.40
# 19                                 4              2.01
# 21                                 1              0.76
# ...                              ...               ...
# 6866                               5               NaN
# 6867                               5              0.35
# 6873                               5               NaN
# 6881                               1              0.28
# 6885                               1              0.55
#
# [1657 rows x 37 columns]

# %%
# Checking for top unique values in each of these variables

df_listings['host_response_time'].value_counts()
# Out:
# within an hour        2942
# within a few hours    1251
# within a day           939
# a few days or more     104
# Name: host_response_time, dtype: int64

# %%
df_listings['host_response_rate'].value_counts()[:5]
# Out:
# 100%    4012
# 90%      226
# 97%       89
# 80%       85
# 92%       58
# Name: host_response_rate, dtype: int64

# %%
df_listings['host_acceptance_rate'].value_counts()[:5]
# Out:
# 100%    2337
# 99%      267
# 50%      217
# 0%       199
# 98%      161
# Name: host_acceptance_rate, dtype: int64

# %%
# We will add a new variable 'not provided' for missing values in host_response_time

df_listings['host_response_time'] = df_listings['host_response_time'].fillna('not provided')

# %%
# For host_response_rate & host_acceptance_rate, we can impute either using the median value or using the most common occurence.

# We will follow the latter method. 

df_listings['host_response_rate'] = df_listings['host_response_rate'].fillna(df_listings['host_response_rate'].mode()[0])

df_listings['host_acceptance_rate'] = df_listings['host_acceptance_rate'].fillna(df_listings['host_acceptance_rate'].mode()[0])

# %%
# We will fill the missing values of the numerical variables with mean

df_listings['review_scores_rating'] = df_listings['review_scores_rating'].fillna(np.mean(df_listings['review_scores_rating']))

df_listings['reviews_per_month'] = df_listings['reviews_per_month'].fillna(np.mean(df_listings['reviews_per_month']))

df_listings['beds'] = df_listings['beds'].fillna(np.mean(df_listings['beds']))

df_listings['bedrooms'] = df_listings['bedrooms'].fillna(np.mean(df_listings['bedrooms']))

# %%
# Lets check the missing values again

find_missing_cols_perc(df_listings, 0)

df_listings[['host_is_superhost', 'bathrooms_text', 'first_review', 'last_review']].isnull().mean()
# Out:
# Index(['host_is_superhost', 'bathrooms_text', 'first_review', 'last_review',
#        'review_scores_location'],
#       dtype='object')
# host_is_superhost    0.001161
# bathrooms_text       0.002176
# first_review         0.093718
# last_review          0.093718
# dtype: float64

# %%
# The remaining columns have less than 10% missing value and the corresponding rows will be dropped. 

df_listings.dropna(inplace=True)

# %%
df_listings.isnull().sum()
# Out:
# id                                0
# name                              0
# host_name                         0
# host_since                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_has_profile_pic              0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# amenities                         0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# has_availability                  0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# number_of_reviews_l30d            0
# first_review                      0
# last_review                       0
# review_scores_rating              0
# review_scores_location            0
# instant_bookable                  0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %%
df_listings.shape
# Out:
# (6233, 37)

# %% [markdown]
# > We are done with handling missing data in __`df_listings`__. Lets check the missing values in __`df_reviews`__.

# %%
# df_reviews has 'comments' with 14 missing values. We will also remove these rows

df_reviews.isnull().sum()
# Out:
# listing_id     0
# date           0
# comments      14
# dtype: int64

# %%
df_reviews.dropna(inplace=True)

# %% [markdown]
# > We have now dealt with the missing values in the dataframes of our interest. Next we will move on to handling the datatype mistmaches.

# %% [markdown]
# #### Handling data mismatch

# %%
# Let's understand the common datatypes in df_listings dataframe

df_listings.dtypes
# Out:
# id                                  int64
# name                               object
# host_name                          object
# host_since                         object
# host_response_time                 object
# host_response_rate                 object
# host_acceptance_rate               object
# host_is_superhost                  object
# host_has_profile_pic               object
# host_identity_verified             object
# neighbourhood_cleansed             object
# latitude                          float64
# longitude                         float64
# property_type                      object
# room_type                          object
# accommodates                        int64
# bathrooms_text                     object
# bedrooms                          float64
# beds                              float64
# amenities                          object
# price                              object
# minimum_nights                      int64
# maximum_nights                      int64
# has_availability                   object
# availability_30                     int64
# availability_60                     int64
# availability_90                     int64
# availability_365                    int64
# number_of_reviews                   int64
# number_of_reviews_l30d              int64
# first_review                       object
# last_review                        object
# review_scores_rating              float64
# review_scores_location            float64
# instant_bookable                   object
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# dtype: object

# %%
df_listings.head(5)
# Out:
#       id                                               name  host_name  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     Daniel
# 1  20168       Studio with private bathroom in the centre 1  Alexander
# 2  27886  Romantic, stylish B&B houseboat in canal district       Flip
# 3  28871                            Comfortable double room      Edwin
# 4  29051                            Comfortable single room      Edwin
#
#    host_since host_response_time host_response_rate host_acceptance_rate  \
# 0  2008-09-24     within an hour               100%                 100%
# 1  2009-12-02     within an hour               100%                  98%
# 2  2010-03-23     within an hour               100%                 100%
# 3  2010-05-13     within an hour               100%                 100%
# 4  2010-05-13     within an hour               100%                 100%
#
#   host_is_superhost host_has_profile_pic host_identity_verified  ...  \
# 0                 t                    t                      t  ...
# 1                 f                    t                      t  ...
# 2                 f                    t                      t  ...
# 3                 t                    t                      t  ...
# 4                 t                    t                      t  ...
#
#   availability_365  number_of_reviews  number_of_reviews_l30d first_review  \
# 0               14                305                       1   2009-03-30
# 1                0                339                       0   2010-03-02
# 2              121                231                       0   2012-01-09
# 3              117                428                       5   2010-08-22
# 4              160                582                       7   2011-03-16
#
#   last_review  review_scores_rating review_scores_location  instant_bookable  \
# 0  2022-08-30                  4.89                   4.69                 t
# 1  2020-04-09                  4.44                   4.87                 t
# 2  2022-04-24                  4.94                   4.89                 t
# 3  2022-08-24                  4.88                   4.96                 f
# 4  2022-08-29                  4.79                   4.87                 f
#
#    calculated_host_listings_count reviews_per_month
# 0                               1              1.86
# 1                               2              2.22
# 2                               1              1.78
# 3                               2              2.92
# 4                               2              4.16
#
# [5 rows x 37 columns]

# %%
df_listings_obj, df_listings_num = func_return_list_dtypes(df_listings)

print('Object types: {}\n'.format(df_listings_obj))
print('Numeric types: {}'.format(df_listings_num))
# Out:
# Object types: ['name', 'host_name', 'host_since', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood_cleansed', 'property_type', 'room_type', 'bathrooms_text', 'amenities', 'price', 'has_availability', 'first_review', 'last_review', 'instant_bookable']
#
# Numeric types: ['id', 'latitude', 'longitude', 'accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_location', 'calculated_host_listings_count', 'reviews_per_month']

# %% [markdown]
# > The following datatype mismatches will have to be taken care of:
#
# > **`listings`**:
#         > - To be converted to datetime: **`host_since`**, **`first_review`**, **`last_review`**
#         > - To be converted to int/float: **`host_response_rate`**, **`host_acceptance_rate`**, **`bathrooms_text`**, **`price`**
#         > - To be converted to bool: **`host_is_superhost`**, **`host_has_profile_pic`**, **`host_identity_verified`**, **`has_availability`**, **`instant_bookable`**
#
# Data mismatches in other dataframes
#
# > **`calendar`**:
#         > - **`date`**, **`available`** & **`price`** as type `object` and will have to be converted to `datetime`, `bool` and `float` respectively.
#
# > **`reviews`**:
#         > - **`date`** will have to be converted to `datetime`

# %%
# A function to convert datatypes

def convert_datatypes(df, cols_date=[], cols_perc=[], cols_bool=[], cols_curr=[]):
    '''
    Function to convert date columns to datetime format
    
    INPUT:
    df - a dataframe
    cols_date - a list of columns to convert to date
    cols_perc - a list of columns to convert to percentage (float)
    cols_bool - a list of columns to convert to bool
    cols_curr - a list of columns to convert to float
    
    '''
    for col in cols_date:
        if df[col].dtype == 'object':
                try:
                    df[col] = pd.to_datetime(df[col])
                except ValueError:
                    pass
                
    for col in cols_perc:
        if df[col].dtype == 'object':
                try:
                    df[col] = df[col].replace('%', '', regex=True).astype(float)
                    df[col] = df[col] * 0.01
                except ValueError:
                    pass
                
    for col in cols_bool:
        if df[col].dtype == 'object':
                try:
                    df[col] = df[col].apply(lambda x: 1 if x == 't' else 0)
                except ValueError:
                    pass
                
    for col in cols_curr:
        if df[col].dtype == 'object':
                try:
                    df[col] = df[col].replace('[\$,]', '', regex=True).astype(float)
                except ValueError:
                    pass

# %%
# Listings dataframe

cols_listings_date = ['host_since', 'first_review', 'last_review']

cols_listings_perc = ['host_response_rate', 'host_acceptance_rate']

cols_listings_bool = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'has_availability', 'instant_bookable']

cols_listings_curr = ['price']

convert_datatypes(df_listings, cols_listings_date, cols_listings_perc, cols_listings_bool, cols_listings_curr)

# %%
# Calendar dataframe

cols_calendar_date = ['date']

cols_calendar_bool = ['available']

cols_calendar_perc = []

cols_calendar_curr = ['price']

convert_datatypes(df_calendar, cols_calendar_date, cols_calendar_perc, cols_calendar_bool, cols_calendar_curr)

# %%
# Reviews dataframe

cols_reviews_date = ['date']

convert_datatypes(df_reviews, cols_reviews_date)

# %%
# Lets check the datatypes again

df_calendar.dtypes
# Out:
# listing_id                 int64
# date              datetime64[ns]
# available                  int64
# price                    float64
# minimum_nights           float64
# dtype: object

# %%
df_reviews.dtypes
# Out:
# listing_id             int64
# date          datetime64[ns]
# comments              object
# dtype: object

# %%
df_listings.dtypes
# Out:
# id                                         int64
# name                                      object
# host_name                                 object
# host_since                        datetime64[ns]
# host_response_time                        object
# host_response_rate                       float64
# host_acceptance_rate                     float64
# host_is_superhost                          int64
# host_has_profile_pic                       int64
# host_identity_verified                     int64
# neighbourhood_cleansed                    object
# latitude                                 float64
# longitude                                float64
# property_type                             object
# room_type                                 object
# accommodates                               int64
# bathrooms_text                            object
# bedrooms                                 float64
# beds                                     float64
# amenities                                 object
# price                                    float64
# minimum_nights                             int64
# maximum_nights                             int64
# has_availability                           int64
# availability_30                            int64
# availability_60                            int64
# availability_90                            int64
# availability_365                           int64
# number_of_reviews                          int64
# number_of_reviews_l30d                     int64
# first_review                      datetime64[ns]
# last_review                       datetime64[ns]
# review_scores_rating                     float64
# review_scores_location                   float64
# instant_bookable                           int64
# calculated_host_listings_count             int64
# reviews_per_month                        float64
# dtype: object

# %%
# There is one feature in df_listings that is yet to converted and that is 'bathrooms_text'. Let's check it out

df_listings['bathrooms_text'].value_counts()
# Out:
# 1 bath               2503
# 1.5 baths            1744
# 1 private bath        809
# 2 baths               358
# 1 shared bath         315
# 1.5 shared baths      187
# 2.5 baths             141
# 3 baths                71
# 3.5 baths              19
# 0 shared baths         17
# Shared half-bath       17
# 0 baths                14
# Half-bath               8
# 2 shared baths          7
# 4.5 baths               6
# Private half-bath       4
# 5 baths                 4
# 3 shared baths          4
# 4 baths                 3
# 5.5 baths               2
# Name: bathrooms_text, dtype: int64

# %% [markdown]
# > **`'bathrooms_text'`** has a mixture of values from which we will extract the number of bathrooms (numeric). We will ignore the type of the bathroom (shared/private/half) for this analysis.

# %%
# Extracting the number of bathrooms from the 'bathrooms_text' column

df_listings['bathrooms_num'] = df_listings["bathrooms_text"].str.split(" ", expand=True)[0]
df_listings['bathrooms_num'] = df_listings['bathrooms_num'].replace(['Private', 'Half-bath', 'Shared'], 0.5)
df_listings['bathrooms_num'] = df_listings['bathrooms_num'].astype('float')

# %%
df_listings['bathrooms_num'].value_counts()
# Out:
# 1.0    3627
# 1.5    1931
# 2.0     365
# 2.5     141
# 3.0      75
# 0.0      31
# 0.5      29
# 3.5      19
# 4.5       6
# 5.0       4
# 4.0       3
# 5.5       2
# Name: bathrooms_num, dtype: int64

# %%
# We will drop the 'bathrooms_text' column

df_listings.drop(['bathrooms_text'], axis=1, inplace=True)

# %% [markdown]
# > We are now almost done with the data cleaning part. Let's do some sanity checks.

# %% [markdown]
# #### Sanity checks

# %%
# Are there any prices that are equal to zero?

df_listings[df_listings['price']==0]

df_calendar[df_calendar['price']==0]
# Out:
#          listing_id       date  available  price  minimum_nights
# 1108136    42430386 2022-09-07          0    0.0             1.0
# 1108137    42430386 2022-09-08          0    0.0             2.0
# 1108138    42430386 2022-09-09          0    0.0             2.0
# 1108139    42430386 2022-09-10          0    0.0             2.0
# 1108140    42430386 2022-09-11          0    0.0             2.0
# ...             ...        ...        ...    ...             ...
# 1249021    47110768 2023-09-02          0    0.0             1.0
# 1249022    47110768 2023-09-03          0    0.0             1.0
# 1249023    47110768 2023-09-04          0    0.0             1.0
# 1249024    47110768 2023-09-05          0    0.0             1.0
# 1249025    47110768 2023-09-06          0    0.0             1.0
#
# [2190 rows x 5 columns]

# %%
# There are some rows with zero price in the df_calendar dataframe. We will remove these rows. 

df_calendar.drop(df_calendar[df_calendar['price']==0].index, inplace=True)

# Let's check again
df_calendar[df_calendar['price']==0]
# Out:
# Empty DataFrame
# Columns: [listing_id, date, available, price, minimum_nights]
# Index: []

# %%
# Are there any reviews with ratings greater than 5.0?

df_listings[df_listings['review_scores_rating']>5.0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_name, host_since, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, neighbourhood_cleansed, latitude, longitude, property_type, room_type, accommodates, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, has_availability, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_location, instant_bookable, calculated_host_listings_count, reviews_per_month, bathrooms_num]
# Index: []
#
# [0 rows x 37 columns]

# %%
# Are there any reviews which was given before the host listed a property? Maybe for a previous host?

inconsistent_dates = df_listings[df_listings['host_since'].dt.year > df_listings['first_review'].dt.year]
inconsistent_dates
# Out:
#             id                                             name    host_name  \
# 45      307497            Sailing ship group stays in Amsterdam         Dion
# 136     742160            Sailing ship group stays in Amsterdam         Dion
# 584    3388684               Spacious apartment near Vondelpark        Jesse
# 807    5200740              Cozy Bright 1BD Apartment -Oud West       Sairah
# 850    5741450  17th Century Canal Appartement at Prinsengracht       Zhifei
# 879    5950879           4p. modern apartment - rooftop terrace      Olivier
# 1539  13272633       Private 2-bedroom apartment near Artis Zoo  Marie-Renée
# 1588  13692489  Spacious & hip split level home near Vondelpark        Peter
#
#      host_since  host_response_time  host_response_rate  host_acceptance_rate  \
# 45   2018-03-06        not provided                 1.0                  1.00
# 136  2018-03-06        not provided                 1.0                  1.00
# 584  2017-08-30        not provided                 1.0                  1.00
# 807  2018-05-07        not provided                 1.0                  1.00
# 850  2020-08-06        not provided                 1.0                  1.00
# 879  2018-08-27        not provided                 1.0                  1.00
# 1539 2018-12-20      within an hour                 1.0                  1.00
# 1588 2017-07-29  within a few hours                 1.0                  0.94
#
#       host_is_superhost  host_has_profile_pic  host_identity_verified  ...  \
# 45                    0                     1                       1  ...
# 136                   0                     1                       1  ...
# 584                   0                     1                       1  ...
# 807                   0                     1                       1  ...
# 850                   0                     1                       1  ...
# 879                   0                     1                       0  ...
# 1539                  1                     1                       1  ...
# 1588                  1                     1                       1  ...
#
#      number_of_reviews  number_of_reviews_l30d  first_review last_review  \
# 45                 102                       0    2012-09-10  2022-07-10
# 136                113                       0    2013-01-14  2020-09-06
# 584                 33                       0    2014-07-14  2022-08-06
# 807                 42                       2    2015-08-24  2022-08-28
# 850                176                       6    2015-04-06  2022-09-03
# 879                 73                       1    2015-05-04  2022-08-15
# 1539               142                       1    2016-06-08  2022-08-12
# 1588                15                       2    2016-07-24  2022-08-12
#
#      review_scores_rating  review_scores_location  instant_bookable  \
# 45                   4.88                    4.57                 0
# 136                  4.81                    4.51                 0
# 584                  4.68                    4.65                 0
# 807                  4.83                    4.74                 0
# 850                  4.90                    4.98                 0
# 879                  4.92                    4.68                 0
# 1539                 4.66                    4.78                 1
# 1588                 4.79                    4.86                 0
#
#       calculated_host_listings_count reviews_per_month  bathrooms_num
# 45                                 2              0.84            2.5
# 136                                2              0.96            2.5
# 584                                1              0.33            1.0
# 807                                1              0.49            1.0
# 850                                1              1.95            1.0
# 879                                1              0.82            1.0
# 1539                               1              1.87            1.0
# 1588                               3              0.20            1.5
#
# [8 rows x 37 columns]

# %%
# We will remove these rows. 

df_listings.drop(inconsistent_dates.index, inplace=True)

# %%
# Are there any reviews which was given after the last review?

inconsistent_dates = df_listings[df_listings['host_since'].dt.year > df_listings['last_review'].dt.year]
inconsistent_dates
# Out:
# Empty DataFrame
# Columns: [id, name, host_name, host_since, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, neighbourhood_cleansed, latitude, longitude, property_type, room_type, accommodates, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, has_availability, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_location, instant_bookable, calculated_host_listings_count, reviews_per_month, bathrooms_num]
# Index: []
#
# [0 rows x 37 columns]

# %%
inconsistent_dates = df_listings[df_listings['first_review'].dt.year > df_listings['last_review'].dt.year]
inconsistent_dates
# Out:
# Empty DataFrame
# Columns: [id, name, host_name, host_since, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, neighbourhood_cleansed, latitude, longitude, property_type, room_type, accommodates, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, has_availability, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_location, instant_bookable, calculated_host_listings_count, reviews_per_month, bathrooms_num]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# > After having performed the sanity checks on our dataset, let's check the dataframes again.

# %%
df_calendar
# Out:
#          listing_id       date  available  price  minimum_nights
# 0              2818 2022-09-07          0   49.0             3.0
# 1              2818 2022-09-08          0   49.0             3.0
# 2              2818 2022-09-09          0   49.0             3.0
# 3              2818 2022-09-10          0   49.0             3.0
# 4              2818 2022-09-11          0   49.0             3.0
# ...             ...        ...        ...    ...             ...
# 2515206      515088 2023-09-02          1  120.0             2.0
# 2515207      515088 2023-09-03          1  120.0             2.0
# 2515208      515088 2023-09-04          1  120.0             2.0
# 2515209      515088 2023-09-05          1  120.0             2.0
# 2515210      515088 2023-09-06          1  120.0             2.0
#
# [2515211 rows x 5 columns]

# %%
df_calendar.info(), df_calendar.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515211 entries, 0 to 2515210
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       int64
#  3   price           float64
#  4   minimum_nights  float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 95.9 MB
# (None,
#  listing_id        0
#  date              0
#  available         0
#  price             0
#  minimum_nights    0
#  dtype: int64)

# %%
df_listings
# Out:
#             id                                               name  host_name  \
# 0         2818           Quiet Garden View Room & Super Fast WiFi     Daniel
# 1        20168       Studio with private bathroom in the centre 1  Alexander
# 2        27886  Romantic, stylish B&B houseboat in canal district       Flip
# 3        28871                            Comfortable double room      Edwin
# 4        29051                            Comfortable single room      Edwin
# ...        ...                                                ...        ...
# 6888  12690380  Amsterdam, light big house 15 min from citycenter    Lennard
# 6889  15005354                 Perfect family home near Amsterdam        Gea
# 6890  15171981  Child friendly house near Amsterdam - free par...      Ischa
# 6891  17567812  Modern, spacious family home, 5 bedrooms-Amste...      Manon
# 6892  20084434  Single-family house (15m cycling center Amster...  Stéphanie
#
#      host_since  host_response_time  host_response_rate  host_acceptance_rate  \
# 0    2008-09-24      within an hour                1.00                  1.00
# 1    2009-12-02      within an hour                1.00                  0.98
# 2    2010-03-23      within an hour                1.00                  1.00
# 3    2010-05-13      within an hour                1.00                  1.00
# 4    2010-05-13      within an hour                1.00                  1.00
# ...         ...                 ...                 ...                   ...
# 6888 2014-05-03  within a few hours                1.00                  1.00
# 6889 2015-10-13      within an hour                0.67                  0.50
# 6890 2016-09-22      within an hour                1.00                  1.00
# 6891 2016-01-18  a few days or more                0.00                  0.00
# 6892 2015-03-16        within a day                1.00                  0.36
#
#       host_is_superhost  host_has_profile_pic  host_identity_verified  ...  \
# 0                     1                     1                       1  ...
# 1                     0                     1                       1  ...
# 2                     0                     1                       1  ...
# 3                     1                     1                       1  ...
# 4                     1                     1                       1  ...
# ...                 ...                   ...                     ...  ...
# 6888                  0                     1                       1  ...
# 6889                  0                     1                       0  ...
# 6890                  0                     1                       0  ...
# 6891                  0                     1                       0  ...
# 6892                  0                     1                       0  ...
#
#      number_of_reviews  number_of_reviews_l30d  first_review last_review  \
# 0                  305                       1    2009-03-30  2022-08-30
# 1                  339                       0    2010-03-02  2020-04-09
# 2                  231                       0    2012-01-09  2022-04-24
# 3                  428                       5    2010-08-22  2022-08-24
# 4                  582                       7    2011-03-16  2022-08-29
# ...                ...                     ...           ...         ...
# 6888                28                       2    2016-05-02  2022-08-20
# 6889                18                       0    2016-11-26  2022-07-26
# 6890                21                       0    2016-10-18  2022-08-07
# 6891                 8                       0    2017-04-16  2019-08-05
# 6892                22                       4    2017-10-22  2022-08-21
#
#      review_scores_rating  review_scores_location  instant_bookable  \
# 0                    4.89                    4.69                 1
# 1                    4.44                    4.87                 1
# 2                    4.94                    4.89                 1
# 3                    4.88                    4.96                 0
# 4                    4.79                    4.87                 0
# ...                   ...                     ...               ...
# 6888                 4.73                    4.63                 0
# 6889                 5.00                    4.89                 0
# 6890                 4.90                    4.30                 0
# 6891                 5.00                    4.75                 0
# 6892                 4.86                    4.82                 0
#
#       calculated_host_listings_count reviews_per_month  bathrooms_num
# 0                                  1              1.86            1.5
# 1                                  2              2.22            1.0
# 2                                  1              1.78            1.5
# 3                                  2              2.92            1.0
# 4                                  2              4.16            1.0
# ...                              ...               ...            ...
# 6888                               1              0.36            2.5
# 6889                               1              0.26            3.0
# 6890                               1              0.29            2.0
# 6891                               1              0.12            2.0
# 6892                               1              0.37            2.0
#
# [6225 rows x 37 columns]

# %%
df_listings.info(), df_listings.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6225 entries, 0 to 6892
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6225 non-null   int64
#  1   name                            6225 non-null   object
#  2   host_name                       6225 non-null   object
#  3   host_since                      6225 non-null   datetime64[ns]
#  4   host_response_time              6225 non-null   object
#  5   host_response_rate              6225 non-null   float64
#  6   host_acceptance_rate            6225 non-null   float64
#  7   host_is_superhost               6225 non-null   int64
#  8   host_has_profile_pic            6225 non-null   int64
#  9   host_identity_verified          6225 non-null   int64
#  10  neighbourhood_cleansed          6225 non-null   object
#  11  latitude                        6225 non-null   float64
#  12  longitude                       6225 non-null   float64
#  13  property_type                   6225 non-null   object
#  14  room_type                       6225 non-null   object
#  15  accommodates                    6225 non-null   int64
#  16  bedrooms                        6225 non-null   float64
#  17  beds                            6225 non-null   float64
#  18  amenities                       6225 non-null   object
#  19  price                           6225 non-null   float64
#  20  minimum_nights                  6225 non-null   int64
#  21  maximum_nights                  6225 non-null   int64
#  22  has_availability                6225 non-null   int64
#  23  availability_30                 6225 non-null   int64
#  24  availability_60                 6225 non-null   int64
#  25  availability_90                 6225 non-null   int64
#  26  availability_365                6225 non-null   int64
#  27  number_of_reviews               6225 non-null   int64
#  28  number_of_reviews_l30d          6225 non-null   int64
#  29  first_review                    6225 non-null   datetime64[ns]
#  30  last_review                     6225 non-null   datetime64[ns]
#  31  review_scores_rating            6225 non-null   float64
#  32  review_scores_location          6225 non-null   float64
#  33  instant_bookable                6225 non-null   int64
#  34  calculated_host_listings_count  6225 non-null   int64
#  35  reviews_per_month               6225 non-null   float64
#  36  bathrooms_num                   6225 non-null   float64
# dtypes: datetime64[ns](3), float64(11), int64(16), object(7)
# memory usage: 1.8+ MB
# (None,
#  id                                0
#  name                              0
#  host_name                         0
#  host_since                        0
#  host_response_time                0
#  host_response_rate                0
#  host_acceptance_rate              0
#  host_is_superhost                 0
#  host_has_profile_pic              0
#  host_identity_verified            0
#  neighbourhood_cleansed            0
#  latitude                          0
#  longitude                         0
#  property_type                     0
#  room_type                         0
#  accommodates                      0
#  bedrooms                          0
#  beds                              0
#  amenities                         0
#  price                             0
#  minimum_nights                    0
#  maximum_nights                    0
#  has_availability                  0
#  availability_30                   0
#  availability_60                   0
#  availability_90                   0
#  availability_365                  0
#  number_of_reviews                 0
#  number_of_reviews_l30d            0
#  first_review                      0
#  last_review                       0
#  review_scores_rating              0
#  review_scores_location            0
#  instant_bookable                  0
#  calculated_host_listings_count    0
#  reviews_per_month                 0
#  bathrooms_num                     0
#  dtype: int64)

# %%
df_reviews
# Out:
#         listing_id       date  \
# 0             2818 2009-03-30
# 1           515749 2012-07-09
# 2           515749 2012-07-15
# 3             2818 2009-04-24
# 4           515749 2012-08-12
# ...            ...        ...
# 342899    40606723 2022-08-23
# 342900    40606723 2022-08-23
# 342901    40606723 2022-08-24
# 342902    40606723 2022-08-24
# 342903    40606723 2022-08-24
#
#                                                  comments
# 0       Daniel is really cool. The place was nice and ...
# 1       If you want the authentic Amsterdam houseboat ...
# 2       Unique and luxurious to be sure. I couldn't re...
# 3       Daniel is the most amazing host! His place is ...
# 4       My wife and I recently stopped in Amsterdam fo...
# ...                                                   ...
# 342899                                Excelente ubicación
# 342900  Would definitely recommend. Perfect location, ...
# 342901  Hôtel bien situé, personnel d’accueil chaleure...
# 342902  Sehr freundliche Personal. Vom Hotel aus kann ...
# 342903  L’Hotel2Stay si trova in una posizione molto c...
#
# [342890 rows x 3 columns]

# %%
df_reviews.info(), df_reviews.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 342890 entries, 0 to 342903
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  342890 non-null  int64
#  1   date        342890 non-null  datetime64[ns]
#  2   comments    342890 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 10.5+ MB
# (None,
#  listing_id    0
#  date          0
#  comments      0
#  dtype: int64)

# %% [markdown]
# > Now all our dataframes have no missing values and have the right datatypes. Now we can proceed to the next part i.e Data Modeling.
# ___

# %% [markdown]
# ## 4) Data Modeling
#
# In this section we will perform exploratory data analysis and modeling on our dataset and try to the questions we posed earlier.

# %% [markdown]
# #### Question 1
#
# #### Which neighbourhood is the most popular among tourists in Amsterdam? What are the average prices in the neighbourhoods? Is there a trend in the prices and reviews for the neighbourhoods?

# %%
# Let's check the number of listings in different neighborhoods of Amsterdam

figure, axes = plt.subplots(figsize=(16,8));
plt.rcParams.update({'font.size': 16})
df_listings['neighbourhood_cleansed'].value_counts().plot(kind='bar');
axes.set_xlabel('Neighbourhoods in Amsterdam');
axes.set_ylabel('Count (-)');
axes.set_title('Total number of Airbnb properties offered in the different neighborhoods in Amsterdam');

# %%
# Let's check the number of reviews received by listings in different neighborhoods of Amsterdam

figure, axes = plt.subplots(figsize=(16,8));
plt.rcParams.update({'font.size': 16})
df_listings.groupby('neighbourhood_cleansed').sum()['number_of_reviews'].sort_values(ascending=False).plot(kind='bar');
axes.set_xlabel('Neighbourhoods in Amsterdam');
axes.set_ylabel('Total number of reviews');
axes.set_title('Total number of reviews received by different neighbourhoods in Amsterdam');

# %% [markdown]
# > Most number of listings are in 'De Baarsjes-Oud-West' area, followed by 'Centrum-West'. However, based on the number of reviews received, we can see that 'Centrum-West' is the most popular among tourists. This could be because tourists prefer to stay in the center of Amsterdam since it is convenient to visit the most popular tourist atrractions.

# %%
sort = df_listings.groupby(["neighbourhood_cleansed"])['price'].mean().sort_values(ascending=False);

figure, axes = plt.subplots(figsize=(16,8));
sns.barplot(x='neighbourhood_cleansed', y='price', data=df_listings, order=sort.index, palette='GnBu_d');
axes.set_xlabel('Neighbourhoods in Amsterdam');
axes.set_ylabel('Price ($)');
axes.set_title("Average prices of listings in different neighbourhoods in Amsterdam")
plt.xticks(rotation=90);

# %% [markdown]
# > The neighbourhoods that are popular among tourists like 'Centrum-West', Centrum-Oost' and 'De Pijp' seems to have the highest average rent. This is more or less expected!

# %%
# Price per person - We will create a new feature for the price per person in dollars

df_listings['price_pp'] = df_listings['price']/df_listings['accommodates']

df_listings['price_pp'].describe()
# Out:
# count    6225.000000
# mean       75.965910
# std        64.538494
# min         1.875000
# 25%        47.666667
# 50%        65.250000
# 75%        90.750000
# max      3301.500000
# Name: price_pp, dtype: float64

# %% [markdown]
# > There seems to be a listing with a max price per person of around 3300 dollars. This must be an outlier. Let's visualize this data in a distplot.

# %%
figure, axes = plt.subplots(figsize=(16,8));
sns.histplot(df_listings['price_pp']);
axes.set_xlabel('Price per Person per Night');
axes.set_ylabel('Frequency');
axes.set_title('Distribution of prices of listings in Amsterdam');

# %% [markdown]
# > Looking at the distribution plot above, we can see that there are some outliers.

# %%
# We will remove these outliers using Tukey rule

IQR = df_listings['price_pp'].quantile(0.75) - df_listings['price_pp'].quantile(0.25)
lower_bound = df_listings['price_pp'].quantile(0.25) - 3*IQR
upper_bound = df_listings['price_pp'].quantile(0.75) + 3*IQR
lower_bound, upper_bound

#Override lower bound with a positive number 
lower_bound = 0
df_listings = df_listings[(df_listings['price_pp']>lower_bound) & (df_listings['price_pp']<upper_bound)]

# %%
figure, axes = plt.subplots(figsize=(16,8));
sns.histplot(df_listings['price_pp']);
axes.set_xlabel('Price per Person per Night');
axes.set_ylabel('Frequency');
axes.set_title('Distribution of prices of listings in Amsterdam after outlier removal');

# %%
df_listings['price_pp'].describe()
# Out:
# count    6164.000000
# mean       72.855930
# std        35.237428
# min         1.875000
# 25%        47.500000
# 50%        65.000000
# 75%        90.000000
# max       217.750000
# Name: price_pp, dtype: float64

# %% [markdown]
# > The average price per night seems to be around 70 dollars. Now, we will see how this changes for different neighbourhoods

# %%
sort = df_listings.groupby(["neighbourhood_cleansed"])['price_pp'].mean().sort_values(ascending=False);

figure, axes = plt.subplots(figsize=(16,8));
sns.barplot(x='neighbourhood_cleansed', y='price_pp', data=df_listings, order=sort.index, palette='GnBu_d');
axes.set_xlabel('Neighbourhoods in Amsterdam');
axes.set_ylabel('Price per person ($)');
axes.set_title("Average prices per person in different neighbourhoods in Amsterdam")
plt.xticks(rotation=90);

# %%
df_listings_grp_neigh_mean = df_listings.groupby(["neighbourhood_cleansed"]).mean()

# %%
# Let's check the review score recevied by listings based for it's location

fig, axes = plt.subplots(figsize=(16,8))

sns.barplot(data=df_listings_grp_neigh_mean, x=df_listings_grp_neigh_mean.index , y='review_scores_location', order=df_listings_grp_neigh_mean.sort_values('review_scores_location', ascending=False).index, palette='GnBu_d')
axes.set_xlabel('Neighbourhood in Amsterdam');
axes.set_ylabel('Review score for location of a listing');
axes.set_title('Review score for a listing based for its location')
plt.xticks(rotation=90);

# %% [markdown]
# > Popular neighbourhoods like 'Centrum-West', Centrum-Oost' and 'De Pijp' are rated higher for it's location compared to rest of the neighbourhoods. This could be because of their proximity to the tourist attractions in Amsterdam.
#
# > Let's now check if there is any correlation between the price and review score for different neighbourhoods in Amstedam.

# %%
fig, axes = plt.subplots(figsize=(16,8))

sns.regplot('review_scores_location', 'price_pp', data = df_listings_grp_neigh_mean);

add_text = [0, 1, 2, 4, 5, 7, 8, 14, 16, 17, 18, 20, 21]
horizontal = ['left','left','right','left','left','left','left','left','left','right','left','right','left']
vertical = ['bottom','bottom','bottom','top','top','top','top','top','top','bottom','top','bottom','bottom']
for i in range(len(add_text)):
    plt.text(df_listings_grp_neigh_mean['review_scores_location'][add_text[i]],
             df_listings_grp_neigh_mean['price_pp'][add_text[i]], 
             df_listings_grp_neigh_mean.index[add_text[i]],
             horizontalalignment = horizontal[i],
             verticalalignment = vertical[i])
    
axes.set_xlabel('Review score for location');
axes.set_ylabel('Price per person ($)');
axes.set_title('Relationship between review score for location and price per person for listings in Amsterdam');
# Out:
# C:\Users\subash.gireesan\Anaconda3\envs\myDSenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > As seen from the plot above, the prices tend to be higher in neighbourhoods with higher review score for location.
#
# > Let's go back to the question we were trying to answer here.
#
# > #### Which neighbourhood is the most popular among tourists in Amsterdam?
# > - Based on the number of reviews obtained, the most popular neighbourhood among tourists are 'Centrum-West', Centrum-Oost' and 'De Pijp'.
#
# > #### What are the average prices in the neighbourhoods?
# > - In the most popular neighbourhoods like 'Centrum-West', Centrum-Oost' and 'De Pijp', the average price per person per night ranges from 80 to 90 dollars.
#
# > #### Is there a trend in the prices and reviews for the neighbourhoods?
# > - Yes, the prices in the neighbourhoods with higher rating for location are higher than the rest of the neighbourhoods.

# %% [markdown]
# #### Question 2
#
# #### What are the type of listings in Amsterdam and what is their average price? What are the most sought-after amenities provided by hosts in Amsterdam?

# %%
# There are a lot of different types of properties listed in Amsterdam. Let's take a look at them. 

df_listings['property_type'].value_counts()
# Out:
# Entire rental unit                    2249
# Entire condo                           764
# Private room in rental unit            505
# Entire home                            483
# Private room in bed and breakfast      294
# Entire townhouse                       203
# Entire loft                            162
# Private room in home                   143
# Houseboat                              122
# Room in boutique hotel                 117
# Private room in condo                  112
# Private room in houseboat              101
# Private room in townhouse               97
# Private room in guest suite             93
# Entire serviced apartment               89
# Room in hotel                           72
# Boat                                    71
# Private room in boat                    55
# Entire guest suite                      47
# Private room in loft                    42
# Entire guesthouse                       40
# Room in aparthotel                      30
# Entire villa                            24
# Shared room in hostel                   23
# Room in bed and breakfast               22
# Private room in hostel                  18
# Tiny home                               16
# Room in serviced apartment              14
# Entire vacation home                    13
# Private room in guesthouse              12
# Room in hostel                          11
# Entire cottage                          11
# Private room in casa particular         10
# Private room in serviced apartment      10
# Entire place                             9
# Private room in farm stay                8
# Private room                             8
# Farm stay                                7
# Entire chalet                            7
# Entire cabin                             6
# Shared room in rental unit               6
# Private room in villa                    6
# Private room in tiny home                5
# Entire bungalow                          4
# Shared room in houseboat                 4
# Barn                                     3
# Private room in cabin                    2
# Private room in earthen home             2
# Camper/RV                                2
# Shared room in home                      2
# Private room in nature lodge             1
# Tower                                    1
# Shared room in bed and breakfast         1
# Private room in bungalow                 1
# Yurt                                     1
# Private room in island                   1
# Windmill                                 1
# Tent                                     1
# Name: property_type, dtype: int64

# %% [markdown]
# > There are a lot of different property types in Amsterdam, but many of those have only a few listings. Let's check the property types with atleast 100 listings.

# %%
fig, axes = plt.subplots(figsize=(16,8))

property_list = df_listings['property_type'].value_counts().loc[lambda x: x>100].index
df_listings['property_type'].value_counts().loc[lambda x: x>100].plot(kind='bar')
axes.set_xlabel('Property type');
axes.set_ylabel('Number of listings (-)');
axes.set_title('Number of listings for different property types with atleast 100 listings');

# %% [markdown]
# > The vast majority of listings in Amsterdam are of the type where an entire unit/condo is rented out. This could be due to the regulation posed by the Municipality.
#
# > Let's check the average prices in these properties.

# %%
df_prop_mean = df_listings.groupby('property_type').mean()

# %%
figure, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8))

df_prop_mean[df_prop_mean.index.isin(property_list)]['price'].sort_values(ascending=False).plot(kind='bar', ax=ax1)
ax1.set_xlabel('Property type');
ax1.set_ylabel('Price ($)');

df_prop_mean[df_prop_mean.index.isin(property_list)]['price_pp'].sort_values(ascending=False).plot(kind='bar', ax=ax2)
ax2.set_xlabel('Property type');
ax2.set_ylabel('Price per person ($)');

# %% [markdown]
# > From the above plots we can see that, renting an entire houseboat (a tourist attraction) is the most expensive option to stay in Amsterdam. This is expected as some tourists are willing to pay a premium for this unique experience!
#
# > On a per-person basis, hotels, condos and lofts are the most expensive.

# %%
# Let's check the different types of rooms available in Amsterdam

figure, axes = plt.subplots(figsize=(16,4))
df_listings['room_type'].value_counts().sort_values().plot(kind='barh')
axes.set_xlabel('Number of listings (-)');

# %% [markdown]
# > The most common type of listing in Amsterdam is an entire home/apartment. These listings have a rule that it cannot be rented out for more than 30 nights a year. We will check if there are listings that break these rules when we answer the fifth question.
#
# > Let's check the average price based on the room types.

# %%
df_listings_grp_room_mean = df_listings.groupby('room_type').mean()
df_listings_grp_room_median = df_listings.groupby('room_type').median()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8))


sns.barplot(data=df_listings_grp_room_mean, x=df_listings_grp_room_mean.index , y='price', order=df_listings_grp_room_mean.sort_values('price').index, ax=ax1, palette='GnBu_d')
ax1.set_xlabel('Room Type')
ax1.set_ylabel('Price ($)')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90);

sns.barplot(data=df_listings_grp_room_mean, x=df_listings_grp_room_mean.index , y='price_pp', order=df_listings_grp_room_mean.sort_values('price_pp').index, ax=ax2, palette='GnBu_d')
ax2.set_xlabel('Room Type')
ax2.set_ylabel('Price per person ($)')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90);

# %% [markdown]
# > As expected, renting a shared or a private room is cheaper than renting a hotel room or an entire home/apartment.
#
# > Renting a hotel room is cheaper on the whole compared to renting an entire home/apartment.
#
# > On a per person basis, renting an entire home/apartment is just slightly more expensive than renting a room.
#
# > Let's check the popular room types based on the number of reviews.

# %%
# Number of reviews obtained for each room type

figure, axes = plt.subplots(figsize=(16,4))
df_listings.groupby('room_type').sum()['number_of_reviews'].sort_values().plot(kind='barh')
axes.set_xlabel('Number of listings (-)');
axes.set_ylabel('');

# %%
# Top 5 property types with most number of reviews

figure, axes = plt.subplots(figsize=(16,8))
df_listings.groupby('property_type').sum()['number_of_reviews'].sort_values(ascending=False)[0:5].plot(kind='barh')
axes.set_xlabel('Number of reviews (-)');
axes.set_ylabel('');

# %% [markdown]
# > Either renting out an entire home or private rooms in a rental unit seems to be the most obvious choice for new hosts to get into the vacation rental space in Amsterdam.
#
# > Now, let's check the most common number of guests in listings in Amsterdam

# %%
df_listings['accommodates'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8))

df_listings['accommodates'].value_counts().sort_index().plot(kind='bar', ax=ax1)
ax1.set_xlabel('Number of guests');
ax1.set_ylabel('Number of listings');

df_listings.groupby('accommodates').sum()['number_of_reviews'].plot(kind='bar', ax=ax2)
ax2.set_xlabel('Number of guests');
ax2.set_ylabel('Number of reviews (-)');

# %% [markdown]
# > Based on the number of listings and number of reviews, the most common type of listings are for 2 guests, followed by 4 guests.
#
# > As per the regulations set by the Municipality of Amsterdam, holiday rentals and B&Bs can only have a maximum of 4 guests. There are some listings that violates this policy! We will look at the in detail later.
#
# > Now let's see what are the most common amenities provided by hosts in Amsterdam.

# %%
df_listings['amenities']
# Out:
# 0       ["Fire extinguisher", "Private entrance", "Lau...
# 1       ["Wifi", "Refrigerator", "TV", "Fire extinguis...
# 2       ["Safe", "Fire extinguisher", "Hp neutral, eco...
# 3       ["Wifi", "Shampoo", "Refrigerator", "Iron", "F...
# 4       ["Wifi", "Shampoo", "Refrigerator", "Iron", "F...
#                               ...
# 6888    ["Fire extinguisher", "Board games", "Microwav...
# 6889    ["Fire extinguisher", "Microwave", "Free stree...
# 6890    ["Fire extinguisher", "Microwave", "Private en...
# 6891    ["Microwave", "Private entrance", "Oven", "Dis...
# 6892    ["Pocket wifi", "Fire extinguisher", "Microwav...
# Name: amenities, Length: 6164, dtype: object

# %%
# Let's remove the quotation first

amenities_list = df_listings['amenities'].apply(lambda x: [amenity.replace('"', "") for amenity in x.split(",")])
amenities_list
# Out:
# 0       [[Fire extinguisher,  Private entrance,  Laund...
# 1       [[Wifi,  Refrigerator,  TV,  Fire extinguisher...
# 2       [[Safe,  Fire extinguisher,  Hp neutral,  eco ...
# 3       [[Wifi,  Shampoo,  Refrigerator,  Iron,  Fire ...
# 4       [[Wifi,  Shampoo,  Refrigerator,  Iron,  Fire ...
#                               ...
# 6888    [[Fire extinguisher,  Board games,  Microwave,...
# 6889    [[Fire extinguisher,  Microwave,  Free street ...
# 6890    [[Fire extinguisher,  Microwave,  Private entr...
# 6891    [[Microwave,  Private entrance,  Oven,  Dishes...
# 6892    [[Pocket wifi,  Fire extinguisher,  Microwave,...
# Name: amenities, Length: 6164, dtype: object

# %%
# We will Multilabelbinarizer to get the list of iterables

mlb = MultiLabelBinarizer()
label_amenities = pd.DataFrame(mlb.fit_transform(amenities_list), columns=mlb.classes_, index=amenities_list.index)
amenities_count = label_amenities.sum().sort_values(ascending=False)
amenities_count
# Out:
#  Smoke alarm                  5274
#  Kitchen                      4899
#  Hot water                    4844
#  Heating                      4794
#  Hair dryer                   4765
#                               ...
#  Fast wifi \u2013 536 Mbps       1
#  Fast wifi \u2013 527 Mbps       1
#  Fast wifi \u2013 526 Mbps       1
#  Fast wifi \u2013 514 Mbps       1
# [\camping\ oventje oven          1
# Length: 1589, dtype: int64

# %%
# Lets check the top 20 amenities provided by hosts in Amsterdam

df_amenities = pd.DataFrame(data={'Amenity': amenities_count.index, 'Count': aminities_count.values})

plt.figure(figsize=(16, 8))
sns.barplot(x="Amenity", y="Count", data=df_amenities.head(20), palette='GnBu_d')
plt.xticks(rotation=90);

# %% [markdown]
# > Looks like most places provide basic necesseties like kitchen, hot water, heating, hair dryer, refrigerator etc. A new host will need to provide these aminities to stay competitive in the market.

# %% [markdown]
# > Let's go back and answer our second question.
#
# > #### What are the type of listings in Amsterdam and what is their average price?
# > - The most common type of listings are Entire homes/apartments and private rooms in a rental unit. The average price ranges between 60 to 100 dollars per person per night depending on the type of the listing.
#
# > #### What are the most sought-after amenities provided by hosts in Amsterdam?
# > - The most common amenities includes kitchen, hot water, heating, hair dryer, refrigerator etc.

# %% [markdown]
# #### Question 3
#
# #### What time of the year is the demand high for listings in Amsterdam? How does the price of a listing change through the year?

# %% [markdown]
# > -  There are two ways to check this. One is to see when the hosts change the price of their listings. During peak season, the prices should be higher.
# > - The other way is to check the availibility of the listings over an year.
# > - We will use the dataframe **`df_calendar`** for this.

# %%
# Let's create a new feature 'month' using the Datetime method

df_calendar['month'] = pd.DatetimeIndex(df_calendar['date']).month

figure, axes = plt.subplots(figsize=(16,8))
sns.lineplot(x="month", y="price",marker="o", data=df_calendar)
axes.set_xlabel('Month of the year');
axes.set_ylabel('Price ($)');
axes.set_title('Variation in price of listings in Amsterdam through a calendar year')
# Out:
# Text(0.5, 1.0, 'Variation in price of listings in Amsterdam through a calendar year')

# %% [markdown]
# > We can see that the prices are higher in April (King's day on April 27th attracts a lot of tourists) and the highest in August, which is the last month of warm weather in Amsterdam!

# %%
# Let's check the change in availability throught an year. We will create new dataframes for this 

df_available = df_calendar[df_calendar['available'] == 1]

df_not_available = df_calendar[df_calendar['available'] == 0]

figure, axes = plt.subplots(figsize=(16,8))
df_available.groupby(['date']).size().plot()
axes.set_xlabel('Date');
axes.set_ylabel('Number of listings that are available');
axes.set_title('Variation in availibility of listings in Amsterdam through a calendar year');

# %% [markdown]
# > As you can see, more listings are available upto March 2023 compared to the time beyond that. It is possible that the hosts has not updated the price of these listings.

# %%
figure, axes = plt.subplots(figsize=(16,8))
df_available.groupby(['date']).mean()['price'].plot()
axes.set_xlabel('Date');
axes.set_ylabel('Number of listings that are not available');
axes.set_title('Variation in availibility of listings in Amsterdam through a calendar year');

# %%
figure, axes = plt.subplots(figsize=(16,8))
df_not_available.groupby(['date']).mean()['price'].plot()
axes.set_xlabel('Date');
axes.set_ylabel('Price ($)');
axes.set_title('Variation in price of listings in Amsterdam through a calendar year');

# %% [markdown]
# > The spikes are due to weekends when the prices will be higher than weekdays. Let's check if that's the case.

# %%
# Let's check the upper and lower bounds for the prices in df_calendar

# We will remove these outliers using Tukey rule
IQR = df_calendar['price'].quantile(0.75) - df_calendar['price'].quantile(0.25)
lower_bound = df_calendar['price'].quantile(0.25) - 3*IQR
upper_bound = df_calendar['price'].quantile(0.75) + 3*IQR
lower_bound, upper_bound
# Out:
# (-280.0, 665.0)

# %%
df_available['day'] = df_calendar['date'].dt.day_name();
# Out:
# C:\Users\SUBASH~1.GIR\AppData\Local\Temp/ipykernel_7348/2756290008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_available['day'] = df_calendar['date'].dt.day_name();

# %%
lower_bound = 0
df_available = df_available[(df_available['price']>lower_bound) & (df_available['price']<upper_bound)]

# %%
plt.figure(figsize=(15, 8))

my_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.boxplot(x = 'day',  y = 'price', data = df_available, palette="Blues", order=my_order)
# Out:
# <AxesSubplot:xlabel='day', ylabel='price'>

# %%
df_available.groupby('day').mean()['price'].sort_values(ascending=False)
# Out:
# day
# Saturday     235.650716
# Friday       232.472985
# Thursday     219.961663
# Sunday       218.984447
# Wednesday    218.053487
# Tuesday      217.618387
# Monday       217.264812
# Name: price, dtype: float64

# %% [markdown]
# > As you can see it is more expensive to rent on Fridays and Saturdays and cheaper to rent during Mondays-Thursdays.

# %% [markdown]
# > Let's answer the questions we posed.
#
# > #### What time of the year is the demand high for listings in Amsterdam?
# > - The demand for rental units in Amsterdam are high in the month of April and August.
#
# > #### How does the price of a listing change through the year?
# > The prices are highest in the month of April and August. In the days of a week, it is most expensive to rent Fridays and Saturdays.

# %% [markdown]
# > Now let's see if we can predict the price of a listing.
#
# > We will start by creating some new features, creating dummy variables and removing unnecessary features that could lead to overfitting.

# %%
df_listings['amenities_count'] = df_listings['amenities'].str.len();

# %%
def fit_linear_mod(df, response_col, drop_cols, test_size=.3, rand_state=42):
    '''
    INPUT:
    df - a dataframe holding all the variables of interest
    response_col - a string holding the name of the column
    drops_cols - columns to drop for creating the feature set
    test_size - a float between [0,1] about what proportion of data should be in the test dataset
    rand_state - an int that is provided as the random state for splitting the data into training and test
    OUTPUT:
    X - cleaned X matrix (dummy and mean imputation)
    y - cleaned response (just dropped na)
    test_score - float - r2 score on the test data
    train_score - float - r2 score on the test data
    lm_model - model object from sklearn
    X_train, X_test, y_train, y_test - output from sklearn train test split used for optimal model
    This function cleans the data and provides the necessary output for the rest of this notebook.
    '''

    
    df = df.drop(drop_cols, axis=1)
    
    #Pull a list of the column names of the categorical variables
    cat_df = df.select_dtypes(include=['object'])
    cat_cols = cat_df.columns
    
    #dummy all the cat_cols
    for col in  cat_cols:
        df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=True)], axis=1)

    #Split into explanatory and response variables
    X = df.drop(response_col, axis=1)
    y = df[response_col]
    
    # Remove overfitting columns
    
    overfit = []
    for i in X.columns:
        counts = X[i].value_counts()
        zeros = counts.iloc[0]
        if zeros / len(X) * 100 > 95:
            overfit.append(i)
    overfit
    
    X = X.drop(overfit, axis=1)

    #Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=rand_state)

    lm_model = LinearRegression() # Instantiate
    lm_model.fit(X_train, y_train) #Fit

    #Predict using your model
    y_test_preds = lm_model.predict(X_test)
    y_train_preds = lm_model.predict(X_train)

    #Score using your model
    test_score = r2_score(y_test, y_test_preds)
    train_score = r2_score(y_train, y_train_preds)

    return X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test, y_test_preds, y_train_preds

# %%
# Let's look for columns that can be removed

df_listings.columns

# %%
df = df_listings.drop(['id', 'name', 'host_name', 'host_since', 'host_response_time', 'latitude', 'longitude', 'amenities', 'first_review', 'last_review'], axis=1)

# %%
drop_cols = ['price_pp']
response_col = 'price'

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test, y_test_preds, y_train_preds = fit_linear_mod(df, response_col, drop_cols, test_size=.3, rand_state=42)

# %%
X_train.columns

# %%
test_score, train_score

# %%
plt.plot(y_test, y_test_preds, 'o')

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the results
coef_df

# %%
coef_df[coef_df['coefs']>0].sort_values(by='coefs', ascending=False)

# %%
listings[listings['minimum_nights']>30]
# Out:
#                       id                                      listing_url  \
# 173               862411              https://www.airbnb.com/rooms/862411
# 391              1914964             https://www.airbnb.com/rooms/1914964
# 504              2829553             https://www.airbnb.com/rooms/2829553
# 1039             7332860             https://www.airbnb.com/rooms/7332860
# 1046             7382264             https://www.airbnb.com/rooms/7382264
# 1048             7394725             https://www.airbnb.com/rooms/7394725
# 1194             9108470             https://www.airbnb.com/rooms/9108470
# 2012            17688373            https://www.airbnb.com/rooms/17688373
# 2106            18471773            https://www.airbnb.com/rooms/18471773
# 2159            18816109            https://www.airbnb.com/rooms/18816109
# 2205            19183967            https://www.airbnb.com/rooms/19183967
# 2224            19343174            https://www.airbnb.com/rooms/19343174
# 2571            22697827            https://www.airbnb.com/rooms/22697827
# 2711            24193584            https://www.airbnb.com/rooms/24193584
# 2889            26465711            https://www.airbnb.com/rooms/26465711
# 3092            28983337            https://www.airbnb.com/rooms/28983337
# 3415            33026828            https://www.airbnb.com/rooms/33026828
# 3569            35143037            https://www.airbnb.com/rooms/35143037
# 3597            35441950            https://www.airbnb.com/rooms/35441950
# 3802            37834161            https://www.airbnb.com/rooms/37834161
# 3884            38889612            https://www.airbnb.com/rooms/38889612
# 3886            38903493            https://www.airbnb.com/rooms/38903493
# 3901            39085563            https://www.airbnb.com/rooms/39085563
# 4938            51114986            https://www.airbnb.com/rooms/51114986
# 5045            51977144            https://www.airbnb.com/rooms/51977144
# 5046            51977694            https://www.airbnb.com/rooms/51977694
# 5295            53685448            https://www.airbnb.com/rooms/53685448
# 5392  553631860460586972  https://www.airbnb.com/rooms/553631860460586972
# 5446  575719932108860056  https://www.airbnb.com/rooms/575719932108860056
# 5808  641070931390173206  https://www.airbnb.com/rooms/641070931390173206
# 5981  663003116085015499  https://www.airbnb.com/rooms/663003116085015499
# 5998  664383793095034535  https://www.airbnb.com/rooms/664383793095034535
# 6340  703972994129545280  https://www.airbnb.com/rooms/703972994129545280
# 6417             2203816             https://www.airbnb.com/rooms/2203816
# 6500              550401              https://www.airbnb.com/rooms/550401
# 6639            39516887            https://www.airbnb.com/rooms/39516887
# 6728  647693182693976750  https://www.airbnb.com/rooms/647693182693976750
# 6778            52275831            https://www.airbnb.com/rooms/52275831
#
#            scrape_id last_scraped           source  \
# 173   20220907151523   2022-09-07      city scrape
# 391   20220907151523   2022-09-07      city scrape
# 504   20220907151523   2022-09-07      city scrape
# 1039  20220907151523   2022-09-07      city scrape
# 1046  20220907151523   2022-09-07      city scrape
# 1048  20220907151523   2022-09-07  previous scrape
# 1194  20220907151523   2022-09-07      city scrape
# 2012  20220907151523   2022-09-07  previous scrape
# 2106  20220907151523   2022-09-07  previous scrape
# 2159  20220907151523   2022-09-07  previous scrape
# 2205  20220907151523   2022-09-07  previous scrape
# 2224  20220907151523   2022-09-07  previous scrape
# 2571  20220907151523   2022-09-07  previous scrape
# 2711  20220907151523   2022-09-07  previous scrape
# 2889  20220907151523   2022-09-07  previous scrape
# 3092  20220907151523   2022-09-07  previous scrape
# 3415  20220907151523   2022-09-07      city scrape
# 3569  20220907151523   2022-09-07      city scrape
# 3597  20220907151523   2022-09-07      city scrape
# 3802  20220907151523   2022-09-07  previous scrape
# 3884  20220907151523   2022-09-07  previous scrape
# 3886  20220907151523   2022-09-07  previous scrape
# 3901  20220907151523   2022-09-07      city scrape
# 4938  20220907151523   2022-09-07      city scrape
# 5045  20220907151523   2022-09-07      city scrape
# 5046  20220907151523   2022-09-07      city scrape
# 5295  20220907151523   2022-09-07  previous scrape
# 5392  20220907151523   2022-09-07      city scrape
# 5446  20220907151523   2022-09-07      city scrape
# 5808  20220907151523   2022-09-07  previous scrape
# 5981  20220907151523   2022-09-07  previous scrape
# 5998  20220907151523   2022-09-07  previous scrape
# 6340  20220907151523   2022-09-07      city scrape
# 6417  20220907151523   2022-09-07      city scrape
# 6500  20220907151523   2022-09-07      city scrape
# 6639  20220907151523   2022-09-07      city scrape
# 6728  20220907151523   2022-09-07      city scrape
# 6778  20220907151523   2022-09-07      city scrape
#
#                                                    name  \
# 173                  Fancy apartment heart of Amsterdam
# 391           17th Century Monumental House with Garden
# 504               Lovely 2 room apt in ''de Pijp'' 65M2
# 1039                           Room in Amsterdam IJburg
# 1046                  Room in Amsterdam IJburg 2 floor.
# 1048                Light apartment - quiet neighbourh.
# 1194                     Bright apartment with a garden
# 2012  BRIGHT & MODERN | SPACIOUS | ROOFTOP TERRACE |...
# 2106       ★ DUPLEX APARTMENT ★ AMSTERDAM ★ NDSM WARF ★
# 2159                                          Nice room
# 2205   Private cosy place with 24/7 access. And 4 bikes
# 2224    Modern and Luxurious apt in the centre of A'dam
# 2571       Town house in De Pijp. 3 pers max. longterm.
# 2711    ★★★ THE ULTIMATE AMSTERDAM EXPERIENCE ★ A/C ★★★
# 2889    Bright, Stylish Familyhouse, recently renovated
# 3092         Charming & light apartment near Vondelpark
# 3415       Beautiful and spacious family house (220 m2)
# 3569  Large 8 room house with private garden Westerpark
# 3597                       amazing room super fast wifi
# 3802  Apt with rooftop terrace close to Vondelpark ~...
# 3884   ★ STYLISH 2BR APT. ★ GREAT VIEW ★ FREE PARKING ★
# 3886       New and modern apartment near the Vondelpark
# 3901            Design lof with view over the river IJ.
# 4938                   Beautiful apartment in Amsterdam
# 5045  3-bedroom serviced apartment in Amsterdam oud-...
# 5046          1 bed studio with private kitchen, shower
# 5295   ★ NEW ★ COSY APARTMENT ★ BALCONY ★ CITY CENTER ★
# 5392       Lovely cosy artistic ground floor apartment.
# 5446   Lovely 1 bedroom apartment in de Pijp, Amsterdam
# 5808               Authentic Appartment near Vondelpark
# 5981      ★ NICE STUDIO ★ AMSTERDAM CITY CENTER ★ A/C ★
# 5998     ★NEW: CANAL VIEWS ★ CREATIVE TOUCH ★ JORDAAN ★
# 6340                Fantastic Room - Downtown Amsterdam
# 6417  Private loft, stunning view about canal Smal W...
# 6500      Beautiful home close to Amsterdam - long term
# 6639                 twee-onder-een kap nabij Amsterdam
# 6728          Home in Amsterdam zuidoost next to Diemen
# 6778                        Heerlijk apartement te huur
#
#                                             description  \
# 173   In the heart of Amsterdam 'Jordaan' you find m...
# 391   Please be very welcome in our 17th century hou...
# 504   Nice full furinusd appartement in Amsterdam - ...
# 1039  Room in Amsterdam, 12 m2, 15 minutes from the ...
# 1046  Room in Amsterdam, 12 m2, 15 minutes from the ...
# 1048  A great apartment in a quiet neighbourhood, wi...
# 1194  It's a very nice and cozy apartment located in...
# 2012  This is a great apartment for your stay in Ams...
# 2106  The bright living room of this duplex apartmen...
# 2159  Welcome to my cool and comfortable room with a...
# 2205  It's a petite place. In a nice quiet area of t...
# 2224  Modern and serene apartment, with all necessar...
# 2571  This house catlovers  only, our cat  Dolly kee...
# 2711  ★★★★★ PREPARE FOR THE TRIP OF A LIFETIME ★★★★★...
# 2889  Beautiful 3 story house in old town house just...
# 3092  Fully renovated top floor apartment with bath,...
# 3415  Very bright and luxurious 5-bedroom apartment ...
# 3569  Long term stays only!!!<br />Large (290 m2) be...
# 3597  very spacious apartment 100m2 the Room is 15m2...
# 3802  Comfortable spacious apartment (95m2) with wor...
# 3884  You are welcome to stay in our cozy apartment,...
# 3886  A modern apartment located with a roof terrace...
# 3901  Open plan loft with large balcony with view ov...
# 4938  We welkom you to our beautiful apartment in Am...
# 5045  Bring the whole family to this great place wit...
# 5046  Enjoy a stylish experience at this centrally-l...
# 5295  Our cosy and new apartment located 15 mins awa...
# 5392  Wherever you want to go, Vondelpark, de Hallen...
# 5446  here you will find your comfy spot in de Pijp ...
# 5808  Enjoy the central location and authentic charm...
# 5981  This Cosy studio offers all amenities you need...
# 5998  This unique & Stylish 2BR apartment offers the...
# 6340  You will have a big room in my shared spacious...
# 6417  You are very welcome in your private studio/lo...
# 6500  NO GROUPS/ACCEPTED. FAMILIES ONLY PLEASE. <br ...
# 6639  Twee-onder-een-kap woning met oprit voor twee ...
# 6728  Deze geweldige accommodatie staat garant voor ...
# 6778  Ga er gewoon even tussenuit in deze rustgevend...
#
#                                   neighborhood_overview  \
# 173   Must sees top 5<br />1. Anne Frank House, plea...
# 391   It's situated on Realeneiland, a little island...
# 504                                                   .
# 1039  Modern architecture based on the Old city cent...
# 1046  Modern architecture based on the Old city cent...
# 1048                                                NaN
# 1194                                                NaN
# 2012  The Baarsjes/ Amsterdam-West is a district rem...
# 2106  Amsterdam Noord is the new place to be! Lot's ...
# 2159                                                NaN
# 2205  It's situated on Realeneiland, a little island...
# 2224                You will be woken by birds chirping
# 2571  This is wonderful lively area, there are heaps...
# 2711  AMSTERDAM CENTRUM - CITY CENTER + CANAL DISTRI...
# 2889  The area<br /><br /> The Watergraafsmeer distr...
# 3092  Bordering the centre of the city, Oud-West (He...
# 3415  Very bright and luxurious 5-bedroom apartment ...
# 3569  Located in a very lively street the apartment ...
# 3597                                                NaN
# 3802  The apartment located in a peacefull neighbour...
# 3884  Very lively neighbourhood with plenty of shops...
# 3886  I really love this neighbourhood, because it's...
# 3901                                                NaN
# 4938                                                NaN
# 5045                                                NaN
# 5046                                                NaN
# 5295  LOCATED IN BETWEEN AMSTERDAM OLD SOUTH - OLD W...
# 5392  Coolest and lately most wanted area of Amsterd...
# 5446                                                NaN
# 5808                                                NaN
# 5981  The Jordaan is possibly the most famous neighb...
# 5998  The Jordaan is possibly the most famous neighb...
# 6340  Amazing area within the most beautiful neighbo...
# 6417                                                NaN
# 6500  The neighborhood is quiet and picturesque with...
# 6639  Halfweg/Zwanenburg liggen tegen elkaar aan, sl...
# 6728                                                NaN
# 6778                                                NaN
#
#                                             picture_url    host_id  ...  \
# 173   https://a0.muscache.com/pictures/16602138/2e6b...    4520552  ...
# 391   https://a0.muscache.com/pictures/26574001/06e8...    8982547  ...
# 504   https://a0.muscache.com/pictures/48006632/592a...   14465690  ...
# 1039  https://a0.muscache.com/pictures/111494537/73b...   11225917  ...
# 1046  https://a0.muscache.com/pictures/111499205/259...   11225917  ...
# 1048  https://a0.muscache.com/pictures/93842183/e265...    1930105  ...
# 1194  https://a0.muscache.com/pictures/9cdc7962-6133...    7390838  ...
# 2012  https://a0.muscache.com/pictures/miso/Hosting-...  120487586  ...
# 2106  https://a0.muscache.com/pictures/miso/Hosting-...   46691672  ...
# 2159  https://a0.muscache.com/pictures/62c6523d-5d5d...   21681343  ...
# 2205  https://a0.muscache.com/pictures/6471f36d-567a...    8982547  ...
# 2224  https://a0.muscache.com/pictures/d55d5b6c-5e92...   50435166  ...
# 2571  https://a0.muscache.com/pictures/5af0fdd7-a81e...     246493  ...
# 2711  https://a0.muscache.com/pictures/91193b40-673f...   46691672  ...
# 2889  https://a0.muscache.com/pictures/b6e0e70a-f63c...    4417000  ...
# 3092  https://a0.muscache.com/pictures/d1668c69-b48b...     523115  ...
# 3415  https://a0.muscache.com/pictures/ea2b7b41-670e...   79394277  ...
# 3569  https://a0.muscache.com/pictures/6f7c6a2b-3a6c...    1518049  ...
# 3597  https://a0.muscache.com/pictures/miso/Hosting-...   16583473  ...
# 3802  https://a0.muscache.com/pictures/miso/Hosting-...    3648688  ...
# 3884  https://a0.muscache.com/pictures/miso/Hosting-...   38177896  ...
# 3886  https://a0.muscache.com/pictures/9cc5fc5f-a21d...  179227487  ...
# 3901  https://a0.muscache.com/pictures/9188502/cb238...    1406783  ...
# 4938  https://a0.muscache.com/pictures/d635d854-1873...   70200319  ...
# 5045  https://a0.muscache.com/pictures/miso/Hosting-...  269718604  ...
# 5046  https://a0.muscache.com/pictures/miso/Hosting-...  269718604  ...
# 5295  https://a0.muscache.com/pictures/miso/Hosting-...   10960219  ...
# 5392  https://a0.muscache.com/pictures/3ae251c9-7f19...    7017774  ...
# 5446  https://a0.muscache.com/pictures/miso/Hosting-...  192704377  ...
# 5808  https://a0.muscache.com/pictures/2f6b4499-5c71...   24437543  ...
# 5981  https://a0.muscache.com/pictures/miso/Hosting-...   12414776  ...
# 5998  https://a0.muscache.com/pictures/miso/Hosting-...  467794608  ...
# 6340  https://a0.muscache.com/pictures/miso/Hosting-...  452237593  ...
# 6417  https://a0.muscache.com/pictures/30719852/38b1...   10622979  ...
# 6500  https://a0.muscache.com/pictures/13838920/c54a...    2705222  ...
# 6639  https://a0.muscache.com/pictures/ff00dd2b-9fea...   33515533  ...
# 6728  https://a0.muscache.com/pictures/miso/Hosting-...  463847396  ...
# 6778  https://a0.muscache.com/pictures/miso/Hosting-...   58889535  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 173                         4.96                   4.96                4.70
# 391                         5.00                   4.89                4.79
# 504                         4.98                   4.82                4.73
# 1039                        4.84                   4.61                4.69
# 1046                        4.89                   4.73                4.81
# 1048                        4.85                   4.67                4.66
# 1194                        4.95                   4.60                4.80
# 2012                        4.86                   4.72                4.64
# 2106                        4.95                   4.53                4.63
# 2159                        5.00                   4.67                4.46
# 2205                        5.00                   4.90                4.78
# 2224                        4.94                   4.74                4.57
# 2571                        4.93                   4.93                4.74
# 2711                        5.00                   5.00                4.85
# 2889                        5.00                   4.88                4.59
# 3092                        5.00                   4.88                4.66
# 3415                        5.00                   4.92                4.92
# 3569                         NaN                    NaN                 NaN
# 3597                         NaN                    NaN                 NaN
# 3802                        5.00                   4.50                4.75
# 3884                        5.00                   4.86                5.00
# 3886                        5.00                   5.00                4.86
# 3901                         NaN                    NaN                 NaN
# 4938                        4.92                   4.75                4.92
# 5045                         NaN                    NaN                 NaN
# 5046                        3.50                   5.00                4.50
# 5295                        5.00                   5.00                5.00
# 5392                         NaN                    NaN                 NaN
# 5446                         NaN                    NaN                 NaN
# 5808                        5.00                   5.00                5.00
# 5981                        5.00                   5.00                5.00
# 5998                        5.00                   5.00                4.40
# 6340                         NaN                    NaN                 NaN
# 6417                        4.97                   4.66                4.88
# 6500                        5.00                   4.92                4.83
# 6639                        5.00                   5.00                5.00
# 6728                        5.00                   5.00                5.00
# 6778                         NaN                    NaN                 NaN
#
#                        license instant_bookable  \
# 173   0363 2A3E E12A B662 839B                f
# 391   0363 7C32 C932 83D2 F5D8                f
# 504   ABCD 1234 AB12 89EF A0F9                f
# 1039                    Exempt                f
# 1046                    Exempt                f
# 1048  0363 ED9D D582 73F0 0D4D                f
# 1194  0363 D913 25D4 1A59 7280                f
# 2012  0363 77DE CF40 AC72 06A7                f
# 2106  0363 5F75 487F 8C50 AF40                f
# 2159  0363 80E2 0920 0E13 6E13                f
# 2205  0363 7C32 C932 83D2 F5D8                f
# 2224  0363 437A 46CA C3B3 DCF3                f
# 2571  0363 EB69 FDB5 5116 D5EC                f
# 2711  0363 7A78 2957 7BF1 6AE7                f
# 2889  0363 D1D1 ED33 4BB8 A00E                f
# 3092  0363 EFDC 299E C8C7 BE7F                f
# 3415  0363 60FB 479C A6A0 5E45                f
# 3569  0363 C1D4 227D E9D4 A3E6                f
# 3597  0363 6F74 7039 016A 3B7A                f
# 3802      0363ADE61E04E713E6DE                f
# 3884  0363 A61D B600 FBD3 648B                f
# 3886  0363 6F19 5020 DCE4 AD4C                f
# 3901  0363 63C6 9755 A0EA 2EC6                f
# 4938  0363 3E90 0C17 8062 1C2D                f
# 5045                    Exempt                t
# 5046                    Exempt                t
# 5295  0363 84AA 051E C491 310B                f
# 5392  0363 57EC E0E4 6325 7B70                t
# 5446  0363 5AAF F3F8 7545 3CB0                f
# 5808  0363 9EEE 445F B6CE 6143                f
# 5981      03631149EE1AD34C21B9                f
# 5998      0363B7015656D87F8AEB                f
# 6340  0363 BBD4 BF33 BE09 7155                f
# 6417                       NaN                t
# 6500                       NaN                f
# 6639                       NaN                t
# 6728                       NaN                f
# 6778                       NaN                f
#
#      calculated_host_listings_count  \
# 173                               1
# 391                               2
# 504                               1
# 1039                              2
# 1046                              2
# 1048                              1
# 1194                              1
# 2012                              1
# 2106                              9
# 2159                              2
# 2205                              2
# 2224                              2
# 2571                              1
# 2711                              9
# 2889                              1
# 3092                              1
# 3415                              1
# 3569                              1
# 3597                              2
# 3802                              1
# 3884                              1
# 3886                              1
# 3901                              2
# 4938                              1
# 5045                              2
# 5046                              2
# 5295                              1
# 5392                              1
# 5446                              1
# 5808                              1
# 5981                              1
# 5998                              1
# 6340                              1
# 6417                              2
# 6500                              1
# 6639                              1
# 6728                              4
# 6778                              1
#
#      calculated_host_listings_count_entire_homes  \
# 173                                            1
# 391                                            1
# 504                                            1
# 1039                                           0
# 1046                                           0
# 1048                                           1
# 1194                                           1
# 2012                                           1
# 2106                                           8
# 2159                                           1
# 2205                                           1
# 2224                                           2
# 2571                                           1
# 2711                                           8
# 2889                                           1
# 3092                                           1
# 3415                                           1
# 3569                                           1
# 3597                                           0
# 3802                                           1
# 3884                                           1
# 3886                                           1
# 3901                                           2
# 4938                                           1
# 5045                                           2
# 5046                                           2
# 5295                                           1
# 5392                                           1
# 5446                                           1
# 5808                                           1
# 5981                                           1
# 5998                                           1
# 6340                                           0
# 6417                                           1
# 6500                                           1
# 6639                                           1
# 6728                                           4
# 6778                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 173                                             0
# 391                                             1
# 504                                             0
# 1039                                            2
# 1046                                            2
# 1048                                            0
# 1194                                            0
# 2012                                            0
# 2106                                            1
# 2159                                            1
# 2205                                            1
# 2224                                            0
# 2571                                            0
# 2711                                            1
# 2889                                            0
# 3092                                            0
# 3415                                            0
# 3569                                            0
# 3597                                            2
# 3802                                            0
# 3884                                            0
# 3886                                            0
# 3901                                            0
# 4938                                            0
# 5045                                            0
# 5046                                            0
# 5295                                            0
# 5392                                            0
# 5446                                            0
# 5808                                            0
# 5981                                            0
# 5998                                            0
# 6340                                            1
# 6417                                            1
# 6500                                            0
# 6639                                            0
# 6728                                            0
# 6778                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 173                                            0              0.69
# 391                                            0              0.27
# 504                                            0              0.45
# 1039                                           0              3.83
# 1046                                           0              3.72
# 1048                                           0              0.48
# 1194                                           0              0.24
# 2012                                           0              0.58
# 2106                                           0              0.29
# 2159                                           0              0.40
# 2205                                           0              1.68
# 2224                                           0              0.57
# 2571                                           0              0.76
# 2711                                           0              0.54
# 2889                                           0              0.35
# 3092                                           0              0.87
# 3415                                           0              0.30
# 3569                                           0               NaN
# 3597                                           0               NaN
# 3802                                           0              1.97
# 3884                                           0              3.89
# 3886                                           0              0.45
# 3901                                           0               NaN
# 4938                                           0              1.06
# 5045                                           0               NaN
# 5046                                           0              0.19
# 5295                                           0              0.50
# 5392                                           0               NaN
# 5446                                           0               NaN
# 5808                                           0              1.96
# 5981                                           0              2.00
# 5998                                           0              3.85
# 6340                                           0               NaN
# 6417                                           0              0.77
# 6500                                           0              0.12
# 6639                                           0              0.08
# 6728                                           0              0.46
# 6778                                           0               NaN
#
# [38 rows x 75 columns]

# %%
listings[listings['host_listings_count']>100]
# Out:
#                       id                                      listing_url  \
# 1252             9816257             https://www.airbnb.com/rooms/9816257
# 1258             9903960             https://www.airbnb.com/rooms/9903960
# 2588            22872252            https://www.airbnb.com/rooms/22872252
# 5004            51572428            https://www.airbnb.com/rooms/51572428
# 6461            52998638            https://www.airbnb.com/rooms/52998638
# 6464            52998236            https://www.airbnb.com/rooms/52998236
# 6677            23347675            https://www.airbnb.com/rooms/23347675
# 6810  685889098772826537  https://www.airbnb.com/rooms/685889098772826537
#
#            scrape_id last_scraped       source  \
# 1252  20220907151523   2022-09-07  city scrape
# 1258  20220907151523   2022-09-07  city scrape
# 2588  20220907151523   2022-09-07  city scrape
# 5004  20220907151523   2022-09-07  city scrape
# 6461  20220907151523   2022-09-07  city scrape
# 6464  20220907151523   2022-09-07  city scrape
# 6677  20220907151523   2022-09-07  city scrape
# 6810  20220907151523   2022-09-07  city scrape
#
#                                                    name  \
# 1252         Houseboat studio with canal view and bikes
# 1258               Classy Room 17th Century Canal House
# 2588  Apartment on great location in the centre of A...
# 5004                Bb 1971 Hazenstraat shared bathroom
# 6461       EuroParcs Poort van Amsterdam for 12 persons
# 6464        EuroParcs Poort van Amsterdam for 8 persons
# 6677    Spacious home large sunny garden Halfweg Sleeps
# 6810  Spacious nice house near Amsterdam city centre...
#
#                                             description  \
# 1252  Private studioroom on a houseboat with a stunn...
# 1258  Private double room in a canal house dating fr...
# 2588  This is a beautiful 2-bedroom apartment in the...
# 5004  This cozy private room witch shared bathroom s...
# 6461  Note: You can directly book the best price if ...
# 6464  Note: You can directly book the best price if ...
# 6677  Surrounded by water, this beautiful cosy free ...
# 6810  Trainstation Halfweg / Zwanenburg just 10 (wal...
#
#                                   neighborhood_overview  \
# 1252  Amsterdam is one of the greatest small cities ...
# 1258  In my neighbourhood, there are lots of things ...
# 2588                                                NaN
# 5004  The apartment is in the heart of Amsterdam cen...
# 6461                                                NaN
# 6464                                                NaN
# 6677  This home is located next to the water which c...
# 6810                                                NaN
#
#                                             picture_url    host_id  ...  \
# 1252  https://a0.muscache.com/pictures/prohost-api/H...     517215  ...
# 1258  https://a0.muscache.com/pictures/d7d7609c-6305...     517215  ...
# 2588  https://a0.muscache.com/pictures/cea0b565-370d...  121985032  ...
# 5004  https://a0.muscache.com/pictures/prohost-api/H...     517215  ...
# 6461  https://a0.muscache.com/pictures/prohost-api/H...  150438407  ...
# 6464  https://a0.muscache.com/pictures/prohost-api/H...  150438407  ...
# 6677  https://a0.muscache.com/pictures/prohost-api/H...     517215  ...
# 6810  https://a0.muscache.com/pictures/prohost-api/H...  201720555  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 1252                        4.93                   4.65                4.69
# 1258                        4.91                   4.98                4.75
# 2588                        4.86                   5.00                4.52
# 5004                        4.88                   5.00                4.54
# 6461                         NaN                    NaN                 NaN
# 6464                        4.60                   4.40                4.40
# 6677                        4.58                   4.54                4.67
# 6810                         NaN                    NaN                 NaN
#
#                        license instant_bookable  \
# 1252  0363 904F 6149 1902 8FAF                t
# 1258  0363 3223 E976 5314 BBB1                t
# 2588                    Exempt                t
# 5004  0363 6876 27B5 F4AD 09D8                t
# 6461                       NaN                t
# 6464                       NaN                t
# 6677                       NaN                t
# 6810                       NaN                t
#
#      calculated_host_listings_count  \
# 1252                              4
# 1258                              4
# 2588                              1
# 5004                              4
# 6461                              2
# 6464                              2
# 6677                              4
# 6810                              1
#
#      calculated_host_listings_count_entire_homes  \
# 1252                                           1
# 1258                                           1
# 2588                                           1
# 5004                                           1
# 6461                                           2
# 6464                                           2
# 6677                                           1
# 6810                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 1252                                            3
# 1258                                            3
# 2588                                            0
# 5004                                            3
# 6461                                            0
# 6464                                            0
# 6677                                            3
# 6810                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 1252                                           0              0.96
# 1258                                           0              6.21
# 2588                                           0              0.62
# 5004                                           0              1.88
# 6461                                           0               NaN
# 6464                                           0              1.00
# 6677                                           0              0.58
# 6810                                           0               NaN
#
# [8 rows x 75 columns]

# %%
listings['host_listings_count'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
